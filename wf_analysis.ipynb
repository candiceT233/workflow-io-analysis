# %%
from sklearn import preprocessing
from sklearn.metrics import mean_absolute_percentage_error, r2_score, mean_absolute_percentage_error


# For 2D analysis
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from scipy.optimize import curve_fit
from sklearn.preprocessing import MinMaxScaler
# from utils import period2freq, freq2period

# For PCA
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from scipy.optimize import curve_fit

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import json
import csv
import time
import glob
import os

MULTI_NODES = False # True: uses tasksPerNodes; False: uses parallelism
NORMALIZE = False
INITIAL_STAGE = False
DEBUG = True

# Datasize in KB
data_size_kb = {'4mb': 4096, '16mb': 16384, '64mb': 65536,
            '256mb': 262144, '512mb': 524288, '1gb': 1048576,
            '5gb': 5242880, '50gb': 52428800, '100gb': 104857600,
            '300gb': 314572800,}

# Key Parameters
WF_PARAMS = ['operation', 'randomOffset', 'transferSize', 
            'aggregateFilesizeMB', 'numTasks', 'parallelism', 'totalTime', 
            'numNodesList', 'numNodes', 'tasksPerNode', 'trMiB', 'storageType',
            'opCount','taskName','taskPID', 'fileName', 'stageOrder']

TARGET_PARAMS = [ "bestStorage" ]
op_dict = {0: "write", 1: "read"}

test_configs = {
    "1kg": {
        "SCRIPT_ORDER": "1kg_script_order",
        "NUM_NODES": 10,
        "exp_data_path": ".", 
        "test_folders": ['par_6000_10n_PFS_ps300'] 
    }
}

# Load experiment data
CURR_WF="1kg"

SCRIPT_ORDER = test_configs[CURR_WF]["SCRIPT_ORDER"]
NUM_NODES = test_configs[CURR_WF]["NUM_NODES"]
exp_data_path = test_configs[CURR_WF]["exp_data_path"]
test_folders = test_configs[CURR_WF]["test_folders"]

# %% [markdown]
# # Parameter Notes for Datalife:
# Each entry in the table represent only one single edge in the workflow. An directed edge connects a **fileName** and a **taskName**, representing data access.
#
# ---
# - **operation**: The type of I/O operation {0: "write", 1: "read"}, value 1 represents read (e.g. a directed edge edge from a **fileName** to a **taskName**), value 0 represents write (e.g. a directed edge edge from a **taskName** to a **fileName**)
# - **randomOffset**: The type of data access pattern { 0: "sequential file access", 1: "random file access"}
# - **transferSize**: Average I/O size of the particular I/O operation to a file, calculated from aggregateFilesizeMB/opCount
# - **aggregateFilesizeMB**: Total I/O size of a particular I/O operation to a file for a task
# - **numTasks**: Number of parallel tasks for this particular task
# - **totalTime**: The total I/O time of of a particular I/O operation to a file for a task
# - **numNodes**: Number of nodes used for this particular task
# - **tasksPerNode**: numTasks/numNodes for a task
# - **bwMiB**: transferRate of a particular I/O operation to a file for a task, calculated from aggregateFilesizeMB/totalTime
# - **storageType**: The storage type used in this task. {0: "localssd", 1: "beegfs/pfs", 2: "lustre", 3: "unknown"}
# - **opCount**: the number of I/O operation count of a particular I/O operation to a file for a task
# - **taskName**: the task name that is running for a particular workflow
# - **taskPID**: the task PID
# - **fileName**: the name of file that a I/O operation is for

# %%
def transform_store_code(storage_type):
    if storage_type == "localssd":
        store_code = 0
    elif storage_type == "beegfs" or storage_type == "pfs":
        store_code = 1
    elif storage_type == "lustre":
        store_code = 2
    else:
        store_code = 3
    return store_code

def decode_store_code(store_code):
    if store_code == 0:
        storage_type = "localssd"
    elif store_code == 1:
        storage_type = "beegfs"
    elif store_code == 2:
        storage_type = "lustre"
    else:
        storage_type = "unknown"
    return storage_type

def bytes_to_mb(file_size):
    """
    Convert a file size from bytes to megabytes (MB).
    
    Parameters:
    - file_size (str, int, or float): The file size in bytes (as an int/float) 
      or a string representation with size and unit (e.g., "1024 KiB").
      
    Returns:
    - float: The file size in MB.
    """
    # If file_size is a string, parse the value and unit
    if isinstance(file_size, str):
        size_num, size_unit = file_size.split()
        size_num = float(size_num)
        
        # Convert size to MB based on the unit
        if size_unit == "Bytes" or size_unit == "B":
            return size_num / (1024 ** 2)  # Convert bytes to MB
        elif size_unit == "KiB":
            return size_num / 1024  # Convert KiB to MB
        elif size_unit == "MiB":
            return size_num  # Already in MB
        elif size_unit == "GiB":
            return size_num * 1024  # Convert GiB to MB
        elif size_unit == "TiB":
            return size_num * (1024 ** 2)  # Convert TiB to MB
        else:
            raise ValueError(f"Unknown size unit: {size_unit}")
    elif isinstance(file_size, (int, float)):
        # If file_size is an integer or float, assume it's in bytes
        return file_size / (1024 ** 2)  # Convert bytes to MB
    else:
        raise TypeError("file_size must be a string or a number")

# %%
def is_sequential(numbers):
    if not numbers:  # Check if the list is empty
        return False

    sorted_numbers = sorted(numbers)  # Sort the numbers
    return all(sorted_numbers[i] + 1 == sorted_numbers[i + 1] for i in range(len(sorted_numbers) - 1))


def get_stat_file_pids(all_files):
    # Extract target tasks from blk_files
    target_tasks = set()
    for blk_file in all_files:
        # Get the filename without the path
        filename = os.path.basename(blk_file)
        # repalce ".local" for now
        filename = filename.replace(".local", "")
        
        # Split filename by '.'
        parts = filename.split('.')
        # print(f"get_stat_file_pids() : parts = {parts}")
        if len(parts) >= 3:
            # Get the target task from the -3 extension
            task = parts[-3]
            target_tasks.add(task)
    target_tasks = sorted(target_tasks)
    return target_tasks

import os
import glob
import json

import os
import json

def add_stat_to_df(trial_folder, monitor_timer_stat_io, 
                   operation, fname, task_pid, store_code):
    # Process the file name
    fname = fname.replace(".local", ".")
    fileName = ".".join(fname.split(".")[:-4])  # Remove last 4 extensions
    fileName = os.path.basename(fileName)      # Keep only the basename
    
    if monitor_timer_stat_io[1] == 0:
        monitor_timer_stat_io[1] = 1 # at least 1 operation if has I/O size
        # print(f"Error: opCount is 0 for task_pid[{task_pid}] fileName[{fileName}]")
    
    # Initialize statistics
    tmp_write_stat = {
        'aggregateFilesizeMB': bytes_to_mb(monitor_timer_stat_io[2]),
        'transferSize': monitor_timer_stat_io[2] / monitor_timer_stat_io[1],
        'operation': int(operation),
        'totalTime': monitor_timer_stat_io[0],
        'trMiB': bytes_to_mb(monitor_timer_stat_io[2] / monitor_timer_stat_io[0]),
        'storageType': store_code,
        'opCount': monitor_timer_stat_io[1],
        'taskPID': task_pid,
        'fileName': fileName,
    }
    print(f"fileName = {fileName}")
    
    if tmp_write_stat['totalTime'] > 100:
        print(f"Recorded large totalTime[{monitor_timer_stat_io}] from task_pid[{task_pid}] fileName[{fileName}]")
    
    if "6818-dc111" in task_pid:
        print(f"monitor_timer_stat_io: {monitor_timer_stat_io}")
    
    # Determine operation type
    op = "w" if operation == 0 else "r"
    
    # Ensure the trial folder exists
    if not os.path.exists(trial_folder):
        print(f"Trial folder does not exist: {trial_folder}")
        return tmp_write_stat
    
    # List all files in the trial folder
    all_files = os.listdir(trial_folder)
    # print(f"Total files in {trial_folder}: {len(all_files)}")
    
    # Find matching files using substring matching
    matching_files = [
        os.path.join(trial_folder, file)
        for file in all_files
        if f"{fileName}.{task_pid}.local.{op}" in file
    ]
    
    # if len(matching_files) == 0:
    #     print(f"No matching files found for fileName[{fileName}] task_pid[{task_pid}] op[{op}]")
    # else:
    #     print(f"Found {len(matching_files)} matching files: {matching_files}")
    
    # Process matching files to determine write pattern
    write_pattern = 0  # 0: seq, 1: rand
    for matching_file in matching_files:
        try:
            with open(matching_file) as f:
                w_blk_trace_data = json.load(f)
                blk_list = w_blk_trace_data.get('io_blk_range', [])
                
                # Validate blk_list length
                if len(blk_list) >= 4:
                    if blk_list[3] == -2:
                        write_pattern = 1
                        print(f"Detected random write pattern in file: {matching_file}")
                        break
                else:
                    print(f"Warning: Invalid 'io_blk_range' in file: {matching_file}")
        except Exception as e:
            print(f"Error processing file {matching_file}: {e}")
    
    # Update statistics
    tmp_write_stat['randomOffset'] = write_pattern
    
    return tmp_write_stat

# %%
target_tasks = ["python"] # omit srun from 1kgenome run

all_wf_df = pd.DataFrame(columns=WF_PARAMS)

# Find task PID's input and output to match script name
def get_wf_result_df(tests, WF_PARAMS, target_tasks, storageType="localssd"):
    wf_df = pd.DataFrame(columns=WF_PARAMS)

    # Identify trial folders
    wf_trial_folders = [
        folder for folder in glob.glob(f"{tests}/*")
        if folder.endswith(("t1", "t2", "t3"))
    ]
    print(f"Trial folders: {wf_trial_folders}")

    store_code = transform_store_code(storageType)

    for trial_folder in wf_trial_folders:
        blk_files = glob.glob(f"{trial_folder}/*_blk_trace.json")
        datalife_monitor = glob.glob(f"{trial_folder}/*.datalife.json")
        target_tasks = get_stat_file_pids(blk_files)
        print(f"blk_files count: {len(blk_files)}")
        print(f"datalife_monitor count: {len(datalife_monitor)}")
        print(f"target_tasks: {target_tasks}")

        for datalife_json in datalife_monitor:
            task_pid = os.path.basename(datalife_json).split(".")[1]
            if task_pid not in target_tasks:
                # print(f"Task PID[{task_pid}] not in target_tasks")
                continue

            try:
                with open(datalife_json) as f:
                    datalife_data = json.load(f)
            except json.JSONDecodeError:
                print(f"Error loading file: {datalife_json}")
                continue

            task_name = list(datalife_data.keys())[0]
            monitor_timer_stat = datalife_data[task_name]['monitor']
            system_timer_stat = datalife_data[task_name]['system']
            monitor_timer_targets = ["read", "write"]

            for fname in [f for f in blk_files if f".{task_pid}." in f]:
                op_type = "read" if ".r_blk_trace." in fname else "write"
                monitor_stat = monitor_timer_stat[op_type]
                
                # Extra check if monitor_stat has zero value, use value from the other op_type
                for i in range(len(monitor_stat)):
                    if monitor_stat[i] == 0:
                        if op_type == "read":
                            monitor_stat[i] = monitor_timer_stat["write"][i]
                        else:
                            monitor_stat[i] = monitor_timer_stat["read"][i]

                # if bytes_to_mb(monitor_stat[2]) == 0:
                #     print(f"No {op_type} stat for task_name[{task_name}] task_pid[{task_pid}]")
                #     continue
                
                # taskParallelism = task_name_to_parallelism[task_name]
                tmp_stat = add_stat_to_df(
                    trial_folder, monitor_stat, 
                    1 if op_type == "read" else 0,
                    fname, task_pid, store_code
                )
                wf_df = wf_df._append(tmp_stat, ignore_index=True)

    return wf_df

def get_test_folder_dfs(test_folder, WF_PARAMS, target_tasks,
                        storageType="localssd"):
    folder_dfs = pd.DataFrame(columns=WF_PARAMS)

    for tests in test_folder:
        stat_path = f"{exp_data_path}/{tests}"

        # Generate workflow data
        wf_df = get_wf_result_df(stat_path, WF_PARAMS, target_tasks,
                                 storageType=storageType)
        print(wf_df.head(5))
        print(f"df shape: {wf_df.shape}")

        # Append workflow data to the folder dataframe
        folder_dfs = folder_dfs._append(wf_df, ignore_index=True)
        
    return folder_dfs

wf_pfs_df = pd.DataFrame(columns=WF_PARAMS)



wf_pfs_df = wf_pfs_df._append(get_test_folder_dfs(test_folders, 
                                        WF_PARAMS, target_tasks,
                                        storageType="pfs"), ignore_index=True)
# Out:
# Trial folders: ['./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1']
# blk_files count: 1810
# datalife_monitor count: 1070
# target_tasks: ['13757-dc026', '13765-dc026', '13895-dc026', '13912-dc026', '13926-dc026', '13927-dc026', '13937-dc026', '13973-dc026', '13976-dc026', '14253-dc026', '14383-dc026', '14542-dc026', '14648-dc026', '14738-dc026', '14972-dc026', '14977-dc026', '14980-dc026', '14988-dc026', '14998-dc026', '15007-dc026', '15023-dc026', '15025-dc026', '15028-dc026', '15029-dc026', '15031-dc026', '15033-dc026', '15035-dc026', '15037-dc026', '15039-dc026', '15041-dc026', '15816-dc177', '15818-dc177', '15820-dc177', '15873-dc177', '15876-dc177', '15918-dc026', '15919-dc026', '15921-dc177', '15948-dc177', '15950-dc026', '15980-dc177', '15985-dc177', '15987-dc177', '15989-dc177', '15991-dc177', '15993-dc177', '15995-dc177', '15997-dc177', '15999-dc177', '16001-dc177', '16003-dc177', '16005-dc177', '16008-dc177', '16009-dc177', '16011-dc177', '16013-dc177', '16015-dc177', '16017-dc177', '16019-dc177', '16021-dc177', '16023-dc177', '16032-dc177', '16040-dc177', '16490-dc177', '16492-dc177', '16503-dc177', '17508-dc177', '17520-dc177', '17526-dc026', '17538-dc177', '17546-dc026', '17556-dc177', '17559-dc177', '17561-dc177', '17563-dc177', '17565-dc177', '17567-dc177', '17570-dc177', '17571-dc177', '17573-dc177', '17576-dc177', '17578-dc177', '17652-dc026', '17781-dc026', '17782-dc026', '17786-dc026', '17851-dc026', '17869-dc026', '17870-dc026', '17872-dc026', '17874-dc026', '17876-dc026', '17878-dc026', '17880-dc026', '1900-dc148', '1903-dc148', '1906-dc148', '1909-dc148', '1940-dc148', '194433-dc273', '194452-dc273', '194456-dc273', '194457-dc273', '194458-dc273', '194525-dc273', '194557-dc273', '194563-dc273', '194576-dc273', '194583-dc273', '194623-dc273', '194625-dc273', '194627-dc273', '194629-dc273', '194631-dc273', '194633-dc273', '194635-dc273', '194637-dc273', '194639-dc273', '194641-dc273', '194643-dc273', '194645-dc273', '194647-dc273', '194649-dc273', '194651-dc273', '194653-dc273', '194655-dc273', '194657-dc273', '194660-dc273', '194661-dc273', '194914-dc260', '194924-dc260', '194926-dc260', '194928-dc260', '194930-dc260', '194932-dc260', '194934-dc260', '195006-dc260', '195023-dc260', '195030-dc260', '195053-dc260', '195083-dc260', '195086-dc260', '195088-dc260', '195090-dc260', '195092-dc260', '195094-dc260', '195097-dc260', '195099-dc260', '195101-dc260', '195103-dc260', '195105-dc260', '195107-dc260', '195109-dc260', '195109-dc273', '195111-dc260', '195111-dc273', '195113-dc260', '195115-dc260', '195117-dc260', '195119-dc260', '195121-dc260', '195129-dc273', '195581-dc260', '195582-dc260', '195591-dc260', '1958-dc148', '196116-dc273', '196118-dc273', '196135-dc273', '196142-dc273', '196149-dc273', '196152-dc273', '196166-dc273', '196173-dc273', '196183-dc273', '196185-dc273', '196187-dc273', '196189-dc273', '196191-dc273', '196193-dc273', '1963-dc148', '1965-dc148', '196580-dc260', '196591-dc260', '196621-dc260', '196637-dc260', '196639-dc260', '196641-dc260', '196643-dc260', '196645-dc260', '196647-dc260', '196649-dc260', '196651-dc260', '196653-dc260', '196657-dc260', '196658-dc260', '1968-dc148', '1970-dc148', '1972-dc148', '1974-dc148', '1977-dc148', '1978-dc148', '24989-dc135', '24992-dc135', '25009-dc135', '25020-dc135', '25026-dc135', '25051-dc135', '25078-dc135', '25084-dc135', '25087-dc135', '25106-dc135', '25128-dc135', '25140-dc135', '25142-dc135', '25146-dc135', '25147-dc135', '25149-dc135', '25151-dc135', '25153-dc135', '25155-dc135', '25163-dc135', '25165-dc135', '25166-dc135', '25168-dc135', '25170-dc135', '25172-dc135', '25174-dc135', '25176-dc135', '25179-dc135', '25181-dc135', '25182-dc135', '25630-dc135', '25632-dc135', '25645-dc135', '26649-dc135', '26657-dc135', '26688-dc135', '26698-dc135', '26700-dc135', '26702-dc135', '26704-dc135', '26706-dc135', '26708-dc135', '26710-dc135', '26712-dc135', '26714-dc135', '26716-dc135', '26718-dc135', '28352-dc257', '28372-dc257', '28374-dc257', '28376-dc257', '28440-dc257', '28461-dc257', '28488-dc257', '28505-dc257', '28542-dc257', '28547-dc257', '28549-dc257', '2855 ...
# fileName = chr2n-2201-2401.tar.gz
# monitor_timer_stat_io: [4.895e-05, 1, 81791]
# fileName = ALL.chr2.250000.vcf
# monitor_timer_stat_io: [19.632952451, 309988, 2539397354]
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/ALL.chr2.250000.vcf.6818-dc111.local.r_blk_trace.json
# fileName = columns.txt
# monitor_timer_stat_io: [19.632952451, 309988, 2539397354]
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/columns.txt.6818-dc111.local.r_blk_trace.json
# fileName = ALL.chr3.250000.vcf
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/ALL.chr3.250000.vcf.25051-dc135.local.r_blk_trace.json
# fileName = chr3n-1201-1401.tar.gz
# fileName = columns.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/columns.txt.25051-dc135.local.r_blk_trace.json
# fileName = ALL.chr8.250000.vcf
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/ALL.chr8.250000.vcf.28580-dc257.local.r_blk_trace.json
# fileName = columns.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/columns.txt.28580-dc257.local.r_blk_trace.json
# fileName = chr8n-1401-1601.tar.gz
# fileName = columns.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/columns.txt.25170-dc135.local.r_blk_trace.json
# fileName = ALL.chr3.250000.vcf
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/ALL.chr3.250000.vcf.25170-dc135.local.r_blk_trace.json
# fileName = chr3n-4601-4801.tar.gz
# fileName = ALL.chr10.250000.vcf
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/ALL.chr10.250000.vcf.194433-dc273.local.r_blk_trace.json
# fileName = chr10n-5601-5801.tar.gz
# fileName = columns.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/columns.txt.194433-dc273.local.r_blk_trace.json
# fileName = chr4n.tar.gz
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/chr4n.tar.gz.41406-dc146.local.r_blk_trace.json
# fileName = sifted.SIFT.chr4.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/sifted.SIFT.chr4.txt.41406-dc146.local.r_blk_trace.json
# fileName = chr4-AFR-freq.tar.gz
# fileName = columns.txt
# fileName = chr8n-1-201.tar.gz
# fileName = columns.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/columns.txt.28562-dc257.local.r_blk_trace.json
# fileName = ALL.chr8.250000.vcf
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/ALL.chr8.250000.vcf.28562-dc257.local.r_blk_trace.json
# fileName = chr10n-4401-4601.tar.gz
# fileName = columns.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/columns.txt.194456-dc273.local.r_blk_trace.json
# fileName = ALL.chr10.250000.vcf
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/ALL.chr10.250000.vcf.194456-dc273.local.r_blk_trace.json
# fileName = chr2-EAS-freq.tar.gz
# fileName = columns.txt
# fileName = sifted.SIFT.chr2.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/sifted.SIFT.chr2.txt.8352-dc111.local.r_blk_trace.json
# fileName = chr2n.tar.gz
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/chr2n.tar.gz.8352-dc111.local.r_blk_trace.json
# fileName = chr4-SAS-freq.tar.gz
# fileName = columns.txt
# fileName = chr4n.tar.gz
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/chr4n.tar.gz.41420-dc146.local.r_blk_trace.json
# fileName = sifted.SIFT.chr4.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/sifted.SIFT.chr4.txt.41420-dc146.local.r_blk_trace.json
# fileName = chr9n-2201-2401.tar.gz
# fileName = columns.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/columns.txt.195099-dc260.local.r_blk_trace.json
# fileName = ALL.chr9.250000.vcf
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/ALL.chr9.250000.vcf.195099-dc260.local.r_blk_trace.json
# fileName = sifted.SIFT.chr6.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/sifted.SIFT.chr6.txt.32974-dc155.local.r_blk_trace.json
# fileName = chr6n.tar.gz
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/chr6n.tar.gz.32974-dc155.local.r_blk_trace.json
# fileName = columns.txt
# fileName = chr6-AFR-freq.tar.gz
# fileName = columns.txt
# fileName = chr7n.tar.gz
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/chr7n.tar.gz.17556-dc177.local.r_blk_trace.json
# fileName = sifted.SIFT.chr7.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/sifted.SIFT.chr7.txt.17556-dc177.local.r_blk_trace.json
# fileName = chr7-ALL.tar.gz
# fileName = columns.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/columns.txt.194926-dc260.local.r_blk_trace.json
# fileName = chr9n-5001-5201.tar.gz
# fileName = ALL.chr9.250000.vcf
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/ALL.chr9.250000.vcf.194926-dc260.local.r_blk_trace.json
# fileName = sifted.SIFT.chr9.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/sifted.SIFT.chr9.txt.196647-dc260.local.r_blk_trace.json
# fileName = chr9-EUR-freq.tar.gz
# fileName = columns.txt
# fileName = chr9n.tar.gz
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/chr9n.tar.gz.196647-dc260.local.r_blk_trace.json
# fileName = ALL.chr2.250000.vcf
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/ALL.chr2.250000.vcf.6826-dc111.local.r_blk_trace.json
# fileName = chr2n-4001-4201.tar.gz
# fileName = columns.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/columns.txt.6826-dc111.local.r_blk_trace.json
# fileName = chr7n-5201-5401.tar.gz
# fileName = columns.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/columns.txt.15997-dc177.local.r_blk_trace.json
# fileName = ALL.chr7.250000.vcf
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/ALL.chr7.250000.vcf.15997-dc177.local.r_blk_trace.json
# fileName = chr1n.tar.gz
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/chr1n.tar.gz.17786-dc026.local.r_blk_trace.json
# fileName = sifted.SIFT.chr1.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/sifted.SIFT.chr1.txt.17786-dc026.local.r_blk_trace.json
# fileName = columns.txt
# fileName = chr1-SAS-freq.tar.gz
# fileName = chr9n.tar.gz
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/chr9n.tar.gz.196643-dc260.local.r_blk_trace.json
# fileName = sifted.SIFT.chr9.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/sifted.SIFT.chr9.txt.196643-dc260.local.r_blk_trace.json
# fileName = columns.txt
# fileName = chr9-GBR-freq.tar.gz
# fileName = ALL.chr5.250000.vcf
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/ALL.chr5.250000.vcf.65447-dc148.local.r_blk_trace.json
# fileName = chr5n-1001-1201.tar.gz
# fileName = columns.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/columns.txt.65447-dc148.local.r_blk_trace.json
# fileName = columns.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/columns.txt.65532-dc148.local.r_blk_trace.json
# fileName = ALL.chr5.250000.vcf
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/ALL.chr5.250000.vcf.65532-dc148.local.r_blk_trace.json
# fileName = chr5n-4201-4401.tar.gz
# fileName = chr10n.tar.gz
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/chr10n.tar.gz.196118-dc273.local.r_blk_trace.json
# fileName = columns.txt
# fileName = sifted.SIFT.chr10.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/sifted.SIFT.chr10.txt.196118-dc273.local.r_blk_trace.json
# fileName = chr10-AMR.tar.gz
# fileName = ALL.chr3.250000.vcf
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/ALL.chr3.250000.vcf.25149-dc135.local.r_blk_trace.json
# fileName = chr3n-5401-5601.tar.gz
# fileName = columns.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/columns.txt.25149-dc135.local.r_blk_trace.json
# fileName = ALL.chr10.250000.vcf
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/ALL.chr10.250000.vcf.194452-dc273.local.r_blk_trace.json
# fileName = columns.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/columns.txt.194452-dc273.local.r_blk_trace.json
# fileName = chr10n-3401-3601.tar.gz
# fileName = columns.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/columns.txt.15873-dc177.local.r_blk_trace.json
# fileName = ALL.chr7.250000.vcf
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/ALL.chr7.250000.vcf.15873-dc177.local.r_blk_trace.json
# fileName = chr7n-1401-1601.tar.gz
# fileName = ALL.chr10.phase3_shapeit2_mvncall_integrated_v5.20130502.sites.annotation.vcf
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/ALL.chr10.phase3_shapeit2_mvncall_integrated_v5.20130502.sites.annotation.vcf.195109-dc273.local.r_blk_trace.json
# fileName = sifted.SIFT.chr10.txt
# /tmp/ipykernel_320735/1454156516.py:66: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   wf_df = wf_df._append(tmp_stat, ignore_index=True)
# fileName = SIFT.chr10.vcf
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/SIFT.chr10.vcf.195109-dc273.local.r_blk_trace.json
# fileName = chr3n.tar.gz
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/chr3n.tar.gz.26700-dc135.local.r_blk_trace.json
# fileName = columns.txt
# fileName = sifted.SIFT.chr3.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/sifted.SIFT.chr3.txt.26700-dc135.local.r_blk_trace.json
# fileName = chr3-GBR.tar.gz
# fileName = chr8n.tar.gz
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/chr8n.tar.gz.30109-dc257.local.r_blk_trace.json
# fileName = sifted.SIFT.chr8.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/sifted.SIFT.chr8.txt.30109-dc257.local.r_blk_trace.json
# fileName = chr8-AFR-freq.tar.gz
# fileName = columns.txt
# fileName = chr6n-1401-1601.tar.gz
# fileName = columns.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/columns.txt.31366-dc155.local.r_blk_trace.json
# fileName = ALL.chr6.250000.vcf
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/ALL.chr6.250000.vcf.31366-dc155.local.r_blk_trace.json
# fileName = chr5n-2001-2201.tar.gz
# fileName = columns.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/columns.txt.312-dc148.local.r_blk_trace.json
# fileName = ALL.chr5.250000.vcf
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/ALL.chr5.250000.vcf.312-dc148.local.r_blk_trace.json
# fileName = chr6-ALL-freq.tar.gz
# fileName = columns.txt
# fileName = chr6n.tar.gz
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/chr6n.tar.gz.33028-dc155.local.r_blk_trace.json
# fileName = sifted.SIFT.chr6.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/sifted.SIFT.chr6.txt.33028-dc155.local.r_blk_trace.json
# fileName = chr6n-2001-2201.tar.gz
# fileName = columns.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/columns.txt.31483-dc155.local.r_blk_trace.json
# fileName = ALL.chr6.250000.vcf
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/ALL.chr6.250000.vcf.31483-dc155.local.r_blk_trace.json
# fileName = ALL.chr10.250000.vcf
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/ALL.chr10.250000.vcf.194647-dc273.local.r_blk_trace.json
# fileName = columns.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/columns.txt.194647-dc273.local.r_blk_trace.json
# fileName = chr10n-5801-6001.tar.gz
# fileName = chr8n.tar.gz
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/chr8n.tar.gz.30115-dc257.local.r_blk_trace.json
# fileName = sifted.SIFT.chr8.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/sifted.SIFT.chr8.txt.30115-dc257.local.r_blk_trace.json
# fileName = chr8-GBR-freq.tar.gz
# fileName = columns.txt
# fileName = chr7n-2401-2601.tar.gz
# fileName = columns.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/columns.txt.15876-dc177.local.r_blk_trace.json
# fileName = ALL.chr7.250000.vcf
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/ALL.chr7.250000.vcf.15876-dc177.local.r_blk_trace.json
# fileName = columns.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/columns.txt.39875-dc146.local.r_blk_trace.json
# fileName = ALL.chr4.250000.vcf
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/ALL.chr4.250000.vcf.39875-dc146.local.r_blk_trace.json
# fileName = chr4n-5401-5601.tar.gz
# fileName = columns.txt
# fileName = sifted.SIFT.chr1.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/sifted.SIFT.chr1.txt.17878-dc026.local.r_blk_trace.json
# fileName = chr1n.tar.gz
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/chr1n.tar.gz.17878-dc026.local.r_blk_trace.json
# fileName = chr1-ALL-freq.tar.gz
# fileName = ALL.chr4.phase3_shapeit2_mvncall_integrated_v5.20130502.sites.annotation.vcf
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/ALL.chr4.phase3_shapeit2_mvncall_integrated_v5.20130502.sites.annotation.vcf.40333-dc146.local.r_blk_trace.json
# fileName = sifted.SIFT.chr4.txt
# fileName = SIFT.chr4.vcf
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/SIFT.chr4.vcf.40333-dc146.local.r_blk_trace.json
# fileName = columns.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/columns.txt.25174-dc135.local.r_blk_trace.json
# fileName = ALL.chr3.250000.vcf
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/ALL.chr3.250000.vcf.25174-dc135.local.r_blk_trace.json
# fileName = chr3n-4001-4201.tar.gz
# fileName = sifted.SIFT.chr7.txt
# fileName = ALL.chr7.phase3_shapeit2_mvncall_integrated_v5.20130502.sites.annotation.vcf
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/ALL.chr7.phase3_shapeit2_mvncall_integrated_v5.20130502.sites.annotation.vcf.16492-dc177.local.r_blk_trace.json
# fileName = SIFT.chr7.vcf
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/SIFT.chr7.vcf.16492-dc177.local.r_blk_trace.json
# fileName = chr2n-4601-4801.tar.gz
# fileName = columns.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/columns.txt.6798-dc111.local.r_blk_trace.json
# fileName = ALL.chr2.250000.vcf
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/ALL.chr2.250000.vcf.6798-dc111.local.r_blk_trace.json
# fileName = chr9n-5601-5801.tar.gz
# fileName = columns.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/columns.txt.195097-dc260.local.r_blk_trace.json
# fileName = ALL.chr9.250000.vcf
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/ALL.chr9.250000.vcf.195097-dc260.local.r_blk_trace.json
# fileName = ALL.chr6.250000.vcf
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/ALL.chr6.250000.vcf.31491-dc155.local.r_blk_trace.json
# fileName = columns.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/columns.txt.31491-dc155.local.r_blk_trace.json
# fileName = chr6n-2601-2801.tar.gz
# fileName = chr8-ALL-freq.tar.gz
# fileName = columns.txt
# fileName = sifted.SIFT.chr8.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/sifted.SIFT.chr8.txt.30121-dc257.local.r_blk_trace.json
# fileName = chr8n.tar.gz
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/chr8n.tar.gz.30121-dc257.local.r_blk_trace.json
# fileName = columns.txt
# fileName = sifted.SIFT.chr9.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/sifted.SIFT.chr9.txt.196621-dc260.local.r_blk_trace.json
# fileName = chr9-AFR.tar.gz
# fileName = chr9n.tar.gz
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/chr9n.tar.gz.196621-dc260.local.r_blk_trace.json
# fileName = ALL.chr10.250000.vcf
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/ALL.chr10.250000.vcf.194623-dc273.local.r_blk_trace.json
# fileName = columns.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/columns.txt.194623-dc273.local.r_blk_trace.json
# fileName = chr10n-1001-1201.tar.gz
# fileName = columns.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/columns.txt.31495-dc155.local.r_blk_trace.json
# fileName = chr6n-5801-6001.tar.gz
# fileName = ALL.chr6.250000.vcf
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/ALL.chr6.250000.vcf.31495-dc155.local.r_blk_trace.json
# fileName = chr8n-5001-5201.tar.gz
# fileName = ALL.chr8.250000.vcf
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/ALL.chr8.250000.vcf.28555-dc257.local.r_blk_trace.json
# fileName = columns.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/columns.txt.28555-dc257.local.r_blk_trace.json
# fileName = ALL.chr8.250000.vcf
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/ALL.chr8.250000.vcf.28582-dc257.local.r_blk_trace.json
# fileName = columns.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/columns.txt.28582-dc257.local.r_blk_trace.json
# fileName = chr8n-2001-2201.tar.gz
# fileName = columns.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/columns.txt.39870-dc146.local.r_blk_trace.json
# fileName = chr4n-4801-5001.tar.gz
# fileName = ALL.chr4.250000.vcf
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/ALL.chr4.250000.vcf.39870-dc146.local.r_blk_trace.json
# fileName = chr3n-601-801.tar.gz
# fileName = columns.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/columns.txt.25176-dc135.local.r_blk_trace.json
# fileName = ALL.chr3.250000.vcf
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/ALL.chr3.250000.vcf.25176-dc135.local.r_blk_trace.json
# fileName = ALL.chr5.250000.vcf
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/ALL.chr5.250000.vcf.65483-dc148.local.r_blk_trace.json
# fileName = chr5n-4001-4201.tar.gz
# fileName = columns.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/columns.txt.65483-dc148.local.r_blk_trace.json
# fileName = chr8n-3801-4001.tar.gz
# fileName = columns.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/columns.txt.28542-dc257.local.r_blk_trace.json
# fileName = ALL.chr8.250000.vcf
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/ALL.chr8.250000.vcf.28542-dc257.local.r_blk_trace.json
# fileName = sifted.SIFT.chr10.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/sifted.SIFT.chr10.txt.196183-dc273.local.r_blk_trace.json
# fileName = chr10n.tar.gz
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/chr10n.tar.gz.196183-dc273.local.r_blk_trace.json
# fileName = columns.txt
# fileName = chr10-SAS-freq.tar.gz
# fileName = sifted.SIFT.chr6.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/sifted.SIFT.chr6.txt.32999-dc155.local.r_blk_trace.json
# fileName = chr6-AMR-freq.tar.gz
# fileName = columns.txt
# fileName = chr6n.tar.gz
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/chr6n.tar.gz.32999-dc155.local.r_blk_trace.json
# fileName = chr8n-201-401.tar.gz
# fileName = columns.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/columns.txt.28372-dc257.local.r_blk_trace.json
# fileName = ALL.chr8.250000.vcf
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/ALL.chr8.250000.vcf.28372-dc257.local.r_blk_trace.json
# fileName = columns.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/columns.txt.39752-dc146.local.r_blk_trace.json
# fileName = ALL.chr4.250000.vcf
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/ALL.chr4.250000.vcf.39752-dc146.local.r_blk_trace.json
# fileName = chr4n-4201-4401.tar.gz
# fileName = chr10n.tar.gz
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/chr10n.tar.gz.196189-dc273.local.r_blk_trace.json
# fileName = chr10-AFR.tar.gz
# fileName = columns.txt
# fileName = sifted.SIFT.chr10.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/sifted.SIFT.chr10.txt.196189-dc273.local.r_blk_trace.json
# fileName = chr9n.tar.gz
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/chr9n.tar.gz.196641-dc260.local.r_blk_trace.json
# fileName = chr9-GBR.tar.gz
# fileName = sifted.SIFT.chr9.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/sifted.SIFT.chr9.txt.196641-dc260.local.r_blk_trace.json
# fileName = columns.txt
# fileName = chr9n-2001-2201.tar.gz
# fileName = columns.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/columns.txt.195086-dc260.local.r_blk_trace.json
# fileName = ALL.chr9.250000.vcf
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/ALL.chr9.250000.vcf.195086-dc260.local.r_blk_trace.json
# fileName = chr9n-3801-4001.tar.gz
# fileName = ALL.chr9.250000.vcf
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/ALL.chr9.250000.vcf.195109-dc260.local.r_blk_trace.json
# fileName = columns.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/columns.txt.195109-dc260.local.r_blk_trace.json
# fileName = chr3-SAS-freq.tar.gz
# fileName = columns.txt
# fileName = chr3n.tar.gz
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/chr3n.tar.gz.26714-dc135.local.r_blk_trace.json
# fileName = sifted.SIFT.chr3.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/sifted.SIFT.chr3.txt.26714-dc135.local.r_blk_trace.json
# fileName = columns.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/columns.txt.6811-dc111.local.r_blk_trace.json
# fileName = chr2n-4201-4401.tar.gz
# fileName = ALL.chr2.250000.vcf
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/ALL.chr2.250000.vcf.6811-dc111.local.r_blk_trace.json
# fileName = chr6-EAS.tar.gz
# fileName = sifted.SIFT.chr6.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/sifted.SIFT.chr6.txt.33031-dc155.local.r_blk_trace.json
# fileName = columns.txt
# fileName = chr6n.tar.gz
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/chr6n.tar.gz.33031-dc155.local.r_blk_trace.json
# fileName = columns.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/columns.txt.195101-dc260.local.r_blk_trace.json
# fileName = ALL.chr9.250000.vcf
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/ALL.chr9.250000.vcf.195101-dc260.local.r_blk_trace.json
# fileName = chr9n-1401-1601.tar.gz
# fileName = sifted.SIFT.chr7.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/sifted.SIFT.chr7.txt.17561-dc177.local.r_blk_trace.json
# fileName = chr7n.tar.gz
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/chr7n.tar.gz.17561-dc177.local.r_blk_trace.json
# fileName = chr7-AFR-freq.tar.gz
# fileName = columns.txt
# fileName = ALL.chr5.phase3_shapeit2_mvncall_integrated_v5.20130502.sites.annotation.vcf
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/ALL.chr5.phase3_shapeit2_mvncall_integrated_v5.20130502.sites.annotation.vcf.845-dc148.local.r_blk_trace.json
# fileName = chr6n.tar.gz
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/chr6n.tar.gz.33026-dc155.local.r_blk_trace.json
# fileName = chr6-EUR.tar.gz
# fileName = sifted.SIFT.chr6.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/sifted.SIFT.chr6.txt.33026-dc155.local.r_blk_trace.json
# fileName = columns.txt
# fileName = columns.txt
# fileName = chr2n.tar.gz
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/chr2n.tar.gz.8378-dc111.local.r_blk_trace.json
# fileName = sifted.SIFT.chr2.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/sifted.SIFT.chr2.txt.8378-dc111.local.r_blk_trace.json
# fileName = chr2-AMR-freq.tar.gz
# fileName = ALL.chr8.250000.vcf
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/ALL.chr8.250000.vcf.28376-dc257.local.r_blk_trace.json
# fileName = chr8n-3201-3401.tar.gz
# fileName = columns.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/columns.txt.28376-dc257.local.r_blk_trace.json
# fileName = ALL.chr9.250000.vcf
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/ALL.chr9.250000.vcf.195105-dc260.local.r_blk_trace.json
# fileName = columns.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/columns.txt.195105-dc260.local.r_blk_trace.json
# fileName = chr9n-601-801.tar.gz
# fileName = chr10n-3201-3401.tar.gz
# fileName = ALL.chr10.250000.vcf
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/ALL.chr10.250000.vcf.194639-dc273.local.r_blk_trace.json
# fileName = columns.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/columns.txt.194639-dc273.local.r_blk_trace.json
# fileName = chr10n-4601-4801.tar.gz
# fileName = columns.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/columns.txt.194661-dc273.local.r_blk_trace.json
# fileName = ALL.chr10.250000.vcf
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/ALL.chr10.250000.vcf.194661-dc273.local.r_blk_trace.json
# fileName = sifted.SIFT.chr2.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/sifted.SIFT.chr2.txt.8382-dc111.local.r_blk_trace.json
# fileName = columns.txt
# fileName = chr2-AFR-freq.tar.gz
# fileName = chr2n.tar.gz
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/chr2n.tar.gz.8382-dc111.local.r_blk_trace.json
# fileName = ALL.chr4.phase3_shapeit2_mvncall_integrated_v5.20130502.sites.annotation.vcf
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/ALL.chr4.phase3_shapeit2_mvncall_integrated_v5.20130502.sites.annotation.vcf.40348-dc146.local.r_blk_trace.json
# fileName = ALL.chr1.250000.vcf
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/ALL.chr1.250000.vcf.14542-dc026.local.r_blk_trace.json
# fileName = columns.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/columns.txt.14542-dc026.local.r_blk_trace.json
# fileName = chr1n-5201-5401.tar.gz
# fileName = chr10n-3401-3601.tar.gz
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/chr10n-3401-3601.tar.gz.195111-dc273.local.r_blk_trace.json
# fileName = chr10n-3001-3201.tar.gz
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/chr10n-3001-3201.tar.gz.195111-dc273.local.r_blk_trace.json
# fileName = chr10n-1801-2001.tar.gz
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/chr10n-1801-2001.tar.gz.195111-dc273.local.r_blk_trace.json
# fileName = chr10n-4201-4401.tar.gz
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/chr10n-4201-4401.tar.gz.195111-dc273.local.r_blk_trace.json
# fileName = chr10n-201-401.tar.gz
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/chr10n-201-401.tar.gz.195111-dc273.local.r_blk_trace.json
# fileName = chr10n-4001-4201.tar.gz
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/chr10n-4001-4201.tar.gz.195111-dc273.local.r_blk_trace.json
# fileName = chr10n-5801-6001.tar.gz
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/chr10n-5801-6001.tar.gz.195111-dc273.local.r_blk_trace.json
# fileName = chr10n-1201-1401.tar.gz
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/chr10n-1201-1401.tar.gz.195111-dc273.local.r_blk_trace.json
# fileName = chr10n-4401-4601.tar.gz
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/chr10n-4401-4601.tar.gz.195111-dc273.local.r_blk_trace.json
# fileName = chr10n-2201-2401.tar.gz
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/chr10n-2201-2401.tar.gz.195111-dc273.local.r_blk_trace.json
# fileName = chr10n-1001-1201.tar.gz
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/chr10n-1001-1201.tar.gz.195111-dc273.local.r_blk_trace.json
# fileName = chr10n-1-201.tar.gz
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/chr10n-1-201.tar.gz.195111-dc273.local.r_blk_trace.json
# fileName = chr10n-3801-4001.tar.gz
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/chr10n-3801-4001.tar.gz.195111-dc273.local.r_blk_trace.json
# fileName = chr10n-5401-5601.tar.gz
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/chr10n-5401-5601.tar.gz.195111-dc273.local.r_blk_trace.json
# fileName = chr10n-5001-5201.tar.gz
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/chr10n-5001-5201.tar.gz.195111-dc273.local.r_blk_trace.json
# fileName = chr10n-1401-1601.tar.gz
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/chr10n-1401-1601.tar.gz.195111-dc273.local.r_blk_trace.json
# fileName = chr10n-1601-1801.tar.gz
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/chr10n-1601-1801.tar.gz.195111-dc273.local.r_blk_trace.json
# fileName = chr10n-3601-3801.tar.gz
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/chr10n-3601-3801.tar.gz.195111-dc273.local.r_blk_trace.json
# fileName = chr10n-401-601.tar.gz
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/chr10n-401-601.tar.gz.195111-dc273.local.r_blk_trace.json
# fileName = chr10n.tar.gz
# fileName = chr10n-5201-5401.tar.gz
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/chr10n-5201-5401.tar.gz.195111-dc273.local.r_blk_trace.json
# fileName = chr10n-3201-3401.tar.gz
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/chr10n-3201-3401.tar.gz.195111-dc273.local.r_blk_trace.json
# fileName = chr10n-5601-5801.tar.gz
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/chr10n-5601-5801.tar.gz.195111-dc273.local.r_blk_trace.json
# fileName = chr10n-601-801.tar.gz
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/chr10n-601-801.tar.gz.195111-dc273.local.r_blk_trace.json
# fileName = chr10n-2401-2601.tar.gz
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/chr10n-2401-2601.tar.gz.195111-dc273.local.r_blk_trace.json
# fileName = chr10n-801-1001.tar.gz
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/chr10n-801-1001.tar.gz.195111-dc273.local.r_blk_trace.json
# fileName = chr10n-4801-5001.tar.gz
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/chr10n-4801-5001.tar.gz.195111-dc273.local.r_blk_trace.json
# fileName = chr10n-2001-2201.tar.gz
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/chr10n-2001-2201.tar.gz.195111-dc273.local.r_blk_trace.json
# fileName = chr10n-4601-4801.tar.gz
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/chr10n-4601-4801.tar.gz.195111-dc273.local.r_blk_trace.json
# fileName = chr10n-2801-3001.tar.gz
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/chr10n-2801-3001.tar.gz.195111-dc273.local.r_blk_trace.json
# fileName = chr10n-2601-2801.tar.gz
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/chr10n-2601-2801.tar.gz.195111-dc273.local.r_blk_trace.json
# fileName = chr5n-3201-3401.tar.gz
# fileName = columns.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/columns.txt.65509-dc148.local.r_blk_trace.json
# fileName = ALL.chr5.250000.vcf
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/ALL.chr5.250000.vcf.65509-dc148.local.r_blk_trace.json
# fileName = chr4n-201-401.tar.gz
# fileName = ALL.chr4.250000.vcf
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/ALL.chr4.250000.vcf.39787-dc146.local.r_blk_trace.json
# fileName = columns.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/columns.txt.39787-dc146.local.r_blk_trace.json
# fileName = chr6n-5001-5201.tar.gz
# fileName = ALL.chr6.250000.vcf
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/ALL.chr6.250000.vcf.31393-dc155.local.r_blk_trace.json
# fileName = columns.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/columns.txt.31393-dc155.local.r_blk_trace.json
# fileName = columns.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/columns.txt.322-dc148.local.r_blk_trace.json
# fileName = chr5n-1601-1801.tar.gz
# fileName = ALL.chr5.250000.vcf
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/ALL.chr5.250000.vcf.322-dc148.local.r_blk_trace.json
# fileName = columns.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/columns.txt.31487-dc155.local.r_blk_trace.json
# fileName = chr6n-5601-5801.tar.gz
# fileName = ALL.chr6.250000.vcf
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/ALL.chr6.250000.vcf.31487-dc155.local.r_blk_trace.json
# fileName = sifted.SIFT.chr8.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/sifted.SIFT.chr8.txt.30086-dc257.local.r_blk_trace.json
# fileName = chr8n.tar.gz
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/chr8n.tar.gz.30086-dc257.local.r_blk_trace.json
# fileName = columns.txt
# fileName = chr8-AMR.tar.gz
# fileName = ALL.chr4.250000.vcf
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/ALL.chr4.250000.vcf.39868-dc146.local.r_blk_trace.json
# fileName = columns.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/columns.txt.39868-dc146.local.r_blk_trace.json
# fileName = chr4n-2801-3001.tar.gz
# fileName = columns.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/columns.txt.15980-dc177.local.r_blk_trace.json
# fileName = ALL.chr7.250000.vcf
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/ALL.chr7.250000.vcf.15980-dc177.local.r_blk_trace.json
# fileName = chr7n-3201-3401.tar.gz
# fileName = chr2n-601-801.tar.gz
# fileName = columns.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/columns.txt.6854-dc111.local.r_blk_trace.json
# fileName = ALL.chr2.250000.vcf
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/ALL.chr2.250000.vcf.6854-dc111.local.r_blk_trace.json
# fileName = chr1-AMR.tar.gz
# fileName = sifted.SIFT.chr1.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/sifted.SIFT.chr1.txt.17872-dc026.local.r_blk_trace.json
# fileName = chr1n.tar.gz
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/chr1n.tar.gz.17872-dc026.local.r_blk_trace.json
# fileName = columns.txt
# fileName = chr1n-2601-2801.tar.gz
# fileName = columns.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/columns.txt.13912-dc026.local.r_blk_trace.json
# fileName = ALL.chr1.250000.vcf
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/ALL.chr1.250000.vcf.13912-dc026.local.r_blk_trace.json
# fileName = ALL.chr3.250000.vcf
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/ALL.chr3.250000.vcf.25142-dc135.local.r_blk_trace.json
# fileName = chr3n-4801-5001.tar.gz
# fileName = columns.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/columns.txt.25142-dc135.local.r_blk_trace.json
# fileName = chr5n-201-401.tar.gz
# fileName = ALL.chr5.250000.vcf
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/ALL.chr5.250000.vcf.65370-dc148.local.r_blk_trace.json
# fileName = columns.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/columns.txt.65370-dc148.local.r_blk_trace.json
# fileName = ALL.chr2.250000.vcf
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/ALL.chr2.250000.vcf.6839-dc111.local.r_blk_trace.json
# fileName = columns.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/columns.txt.6839-dc111.local.r_blk_trace.json
# fileName = chr2n-401-601.tar.gz
# fileName = columns.txt
# fileName = chr6-SAS-freq.tar.gz
# fileName = sifted.SIFT.chr6.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/sifted.SIFT.chr6.txt.33016-dc155.local.r_blk_trace.json
# fileName = chr6n.tar.gz
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/chr6n.tar.gz.33016-dc155.local.r_blk_trace.json
# fileName = columns.txt
# fileName = sifted.SIFT.chr2.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/sifted.SIFT.chr2.txt.8361-dc111.local.r_blk_trace.json
# fileName = chr2n.tar.gz
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/chr2n.tar.gz.8361-dc111.local.r_blk_trace.json
# fileName = chr2-SAS.tar.gz
# fileName = columns.txt
# fileName = sifted.SIFT.chr7.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/sifted.SIFT.chr7.txt.17570-dc177.local.r_blk_trace.json
# fileName = chr7-AMR-freq.tar.gz
# fileName = chr7n.tar.gz
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/chr7n.tar.gz.17570-dc177.local.r_blk_trace.json
# fileName = chr3n-3601-3801.tar.gz
# fileName = ALL.chr3.250000.vcf
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/ALL.chr3.250000.vcf.25106-dc135.local.r_blk_trace.json
# fileName = columns.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/columns.txt.25106-dc135.local.r_blk_trace.json
# fileName = chr10n-2401-2601.tar.gz
# fileName = columns.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/columns.txt.194631-dc273.local.r_blk_trace.json
# fileName = ALL.chr10.250000.vcf
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/ALL.chr10.250000.vcf.194631-dc273.local.r_blk_trace.json
# fileName = ALL.chr8.250000.vcf
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/ALL.chr8.250000.vcf.28560-dc257.local.r_blk_trace.json
# fileName = chr8n-3001-3201.tar.gz
# fileName = columns.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/columns.txt.28560-dc257.local.r_blk_trace.json
# fileName = columns.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/columns.txt.15816-dc177.local.r_blk_trace.json
# fileName = chr7n-1801-2001.tar.gz
# fileName = ALL.chr7.250000.vcf
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/ALL.chr7.250000.vcf.15816-dc177.local.r_blk_trace.json
# fileName = columns.txt
# fileName = sifted.SIFT.chr8.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/sifted.SIFT.chr8.txt.30127-dc257.local.r_blk_trace.json
# fileName = chr8-EAS-freq.tar.gz
# fileName = chr8n.tar.gz
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/chr8n.tar.gz.30127-dc257.local.r_blk_trace.json
# fileName = ALL.chr4.250000.vcf
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/ALL.chr4.250000.vcf.39716-dc146.local.r_blk_trace.json
# fileName = chr4n-3201-3401.tar.gz
# fileName = columns.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/columns.txt.39716-dc146.local.r_blk_trace.json
# fileName = columns.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/columns.txt.16021-dc177.local.r_blk_trace.json
# fileName = ALL.chr7.250000.vcf
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/ALL.chr7.250000.vcf.16021-dc177.local.r_blk_trace.json
# fileName = chr7n-3001-3201.tar.gz
# fileName = columns.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/columns.txt.14988-dc026.local.r_blk_trace.json
# fileName = chr1n-3601-3801.tar.gz
# fileName = ALL.chr1.250000.vcf
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/ALL.chr1.250000.vcf.14988-dc026.local.r_blk_trace.json
# fileName = columns.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/columns.txt.31291-dc155.local.r_blk_trace.json
# fileName = chr6n-2401-2601.tar.gz
# fileName = ALL.chr6.250000.vcf
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/ALL.chr6.250000.vcf.31291-dc155.local.r_blk_trace.json
# fileName = columns.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/columns.txt.24992-dc135.local.r_blk_trace.json
# fileName = ALL.chr3.250000.vcf
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/ALL.chr3.250000.vcf.24992-dc135.local.r_blk_trace.json
# fileName = chr3n-1001-1201.tar.gz
# fileName = columns.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/columns.txt.16001-dc177.local.r_blk_trace.json
# fileName = chr7n-4601-4801.tar.gz
# fileName = ALL.chr7.250000.vcf
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/ALL.chr7.250000.vcf.16001-dc177.local.r_blk_trace.json
# fileName = sifted.SIFT.chr8.txt
# fileName = ALL.chr8.phase3_shapeit2_mvncall_integrated_v5.20130502.sites.annotation.vcf
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/ALL.chr8.phase3_shapeit2_mvncall_integrated_v5.20130502.sites.annotation.vcf.29050-dc257.local.r_blk_trace.json
# fileName = SIFT.chr8.vcf
# ...
# fileName = chr2n-1401-1601.tar.gz
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/chr2n-1401-1601.tar.gz.7296-dc111.local.r_blk_trace.json
# fileName = chr2n-1801-2001.tar.gz
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/chr2n-1801-2001.tar.gz.7296-dc111.local.r_blk_trace.json
# fileName = chr2n-5601-5801.tar.gz
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/chr2n-5601-5801.tar.gz.7296-dc111.local.r_blk_trace.json
# fileName = chr2n-3401-3601.tar.gz
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/chr2n-3401-3601.tar.gz.7296-dc111.local.r_blk_trace.json
# fileName = chr2n-4801-5001.tar.gz
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/chr2n-4801-5001.tar.gz.7296-dc111.local.r_blk_trace.json
# fileName = chr2n-1001-1201.tar.gz
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/chr2n-1001-1201.tar.gz.7296-dc111.local.r_blk_trace.json
# fileName = chr2n-5001-5201.tar.gz
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/chr2n-5001-5201.tar.gz.7296-dc111.local.r_blk_trace.json
# fileName = chr2n-801-1001.tar.gz
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/chr2n-801-1001.tar.gz.7296-dc111.local.r_blk_trace.json
# fileName = chr2n-5401-5601.tar.gz
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/chr2n-5401-5601.tar.gz.7296-dc111.local.r_blk_trace.json
# fileName = chr2n-3001-3201.tar.gz
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/chr2n-3001-3201.tar.gz.7296-dc111.local.r_blk_trace.json
# fileName = chr2n-2601-2801.tar.gz
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/chr2n-2601-2801.tar.gz.7296-dc111.local.r_blk_trace.json
# fileName = chr2n-4001-4201.tar.gz
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/chr2n-4001-4201.tar.gz.7296-dc111.local.r_blk_trace.json
# fileName = chr2n-3801-4001.tar.gz
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/chr2n-3801-4001.tar.gz.7296-dc111.local.r_blk_trace.json
# fileName = chr2n-1201-1401.tar.gz
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/chr2n-1201-1401.tar.gz.7296-dc111.local.r_blk_trace.json
# fileName = chr2n-4201-4401.tar.gz
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/chr2n-4201-4401.tar.gz.7296-dc111.local.r_blk_trace.json
# fileName = chr2n-2001-2201.tar.gz
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/chr2n-2001-2201.tar.gz.7296-dc111.local.r_blk_trace.json
# fileName = chr2n-3601-3801.tar.gz
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/chr2n-3601-3801.tar.gz.7296-dc111.local.r_blk_trace.json
# fileName = chr2n-5801-6001.tar.gz
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/chr2n-5801-6001.tar.gz.7296-dc111.local.r_blk_trace.json
# fileName = chr2n-601-801.tar.gz
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/chr2n-601-801.tar.gz.7296-dc111.local.r_blk_trace.json
# fileName = chr2n-2401-2601.tar.gz
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/chr2n-2401-2601.tar.gz.7296-dc111.local.r_blk_trace.json
# fileName = chr2n.tar.gz
# fileName = chr2n-4601-4801.tar.gz
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/chr2n-4601-4801.tar.gz.7296-dc111.local.r_blk_trace.json
# fileName = chr2n-3201-3401.tar.gz
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/chr2n-3201-3401.tar.gz.7296-dc111.local.r_blk_trace.json
# fileName = chr2n-5201-5401.tar.gz
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/chr2n-5201-5401.tar.gz.7296-dc111.local.r_blk_trace.json
# fileName = chr2n-1601-1801.tar.gz
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/chr2n-1601-1801.tar.gz.7296-dc111.local.r_blk_trace.json
# fileName = chr2n-2801-3001.tar.gz
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/chr2n-2801-3001.tar.gz.7296-dc111.local.r_blk_trace.json
# fileName = chr1n-3401-3601.tar.gz
# fileName = ALL.chr1.250000.vcf
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/ALL.chr1.250000.vcf.15031-dc026.local.r_blk_trace.json
# fileName = columns.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/columns.txt.15031-dc026.local.r_blk_trace.json
# fileName = ALL.chr8.phase3_shapeit2_mvncall_integrated_v5.20130502.sites.annotation.vcf
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/ALL.chr8.phase3_shapeit2_mvncall_integrated_v5.20130502.sites.annotation.vcf.29061-dc257.local.r_blk_trace.json
# fileName = ALL.chr6.250000.vcf
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/ALL.chr6.250000.vcf.31396-dc155.local.r_blk_trace.json
# fileName = columns.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/columns.txt.31396-dc155.local.r_blk_trace.json
# fileName = chr6n-1201-1401.tar.gz
# fileName = ALL.chr7.250000.vcf
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/ALL.chr7.250000.vcf.16009-dc177.local.r_blk_trace.json
# fileName = chr7n-5001-5201.tar.gz
# fileName = columns.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/columns.txt.16009-dc177.local.r_blk_trace.json
# fileName = ALL.chr9.250000.vcf
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/ALL.chr9.250000.vcf.195111-dc260.local.r_blk_trace.json
# fileName = chr9n-3601-3801.tar.gz
# fileName = columns.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/columns.txt.195111-dc260.local.r_blk_trace.json
# fileName = ALL.chr7.250000.vcf
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/ALL.chr7.250000.vcf.15985-dc177.local.r_blk_trace.json
# fileName = chr7n-3601-3801.tar.gz
# fileName = columns.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/columns.txt.15985-dc177.local.r_blk_trace.json
# fileName = columns.txt
# fileName = sifted.SIFT.chr5.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/sifted.SIFT.chr5.txt.1970-dc148.local.r_blk_trace.json
# fileName = chr5-SAS.tar.gz
# fileName = chr5n.tar.gz
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/chr5n.tar.gz.1970-dc148.local.r_blk_trace.json
# fileName = columns.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/columns.txt.28374-dc257.local.r_blk_trace.json
# fileName = ALL.chr8.250000.vcf
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/ALL.chr8.250000.vcf.28374-dc257.local.r_blk_trace.json
# fileName = chr8n-5601-5801.tar.gz
# fileName = chr10n-5201-5401.tar.gz
# fileName = columns.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/columns.txt.194563-dc273.local.r_blk_trace.json
# fileName = ALL.chr10.250000.vcf
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/ALL.chr10.250000.vcf.194563-dc273.local.r_blk_trace.json
# fileName = ALL.chr3.250000.vcf
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/ALL.chr3.250000.vcf.25026-dc135.local.r_blk_trace.json
# fileName = chr3n-2601-2801.tar.gz
# fileName = columns.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/columns.txt.25026-dc135.local.r_blk_trace.json
# fileName = chr7n-2001-2201.tar.gz
# fileName = ALL.chr7.250000.vcf
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/ALL.chr7.250000.vcf.16032-dc177.local.r_blk_trace.json
# fileName = columns.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/columns.txt.16032-dc177.local.r_blk_trace.json
# fileName = ALL.chr4.250000.vcf
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/ALL.chr4.250000.vcf.39864-dc146.local.r_blk_trace.json
# fileName = columns.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/columns.txt.39864-dc146.local.r_blk_trace.json
# fileName = chr4n-5601-5801.tar.gz
# fileName = columns.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/columns.txt.39745-dc146.local.r_blk_trace.json
# fileName = chr4n-601-801.tar.gz
# fileName = ALL.chr4.250000.vcf
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/ALL.chr4.250000.vcf.39745-dc146.local.r_blk_trace.json
# fileName = ALL.chr7.250000.vcf
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/ALL.chr7.250000.vcf.16003-dc177.local.r_blk_trace.json
# fileName = chr7n-601-801.tar.gz
# fileName = columns.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/columns.txt.16003-dc177.local.r_blk_trace.json
# fileName = chr1n-5601-5801.tar.gz
# fileName = columns.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/columns.txt.13973-dc026.local.r_blk_trace.json
# fileName = ALL.chr1.250000.vcf
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/ALL.chr1.250000.vcf.13973-dc026.local.r_blk_trace.json
# fileName = columns.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/columns.txt.65535-dc148.local.r_blk_trace.json
# fileName = chr5n-2401-2601.tar.gz
# fileName = ALL.chr5.250000.vcf
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/ALL.chr5.250000.vcf.65535-dc148.local.r_blk_trace.json
# fileName = columns.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/columns.txt.39758-dc146.local.r_blk_trace.json
# fileName = chr4n-2401-2601.tar.gz
# fileName = ALL.chr4.250000.vcf
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/ALL.chr4.250000.vcf.39758-dc146.local.r_blk_trace.json
# fileName = columns.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/columns.txt.31493-dc155.local.r_blk_trace.json
# fileName = chr6n-3001-3201.tar.gz
# fileName = ALL.chr6.250000.vcf
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/ALL.chr6.250000.vcf.31493-dc155.local.r_blk_trace.json
# fileName = columns.txt
# fileName = chr7n.tar.gz
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/chr7n.tar.gz.17538-dc177.local.r_blk_trace.json
# fileName = chr7-AMR.tar.gz
# fileName = sifted.SIFT.chr7.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/sifted.SIFT.chr7.txt.17538-dc177.local.r_blk_trace.json
# fileName = chr6n-1001-1201.tar.gz
# fileName = ALL.chr6.250000.vcf
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/ALL.chr6.250000.vcf.31370-dc155.local.r_blk_trace.json
# fileName = columns.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/columns.txt.31370-dc155.local.r_blk_trace.json
# fileName = columns.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/columns.txt.39882-dc146.local.r_blk_trace.json
# fileName = chr4n-1201-1401.tar.gz
# fileName = ALL.chr4.250000.vcf
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/ALL.chr4.250000.vcf.39882-dc146.local.r_blk_trace.json
# fileName = chr7n-5601-5801.tar.gz
# fileName = columns.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/columns.txt.15921-dc177.local.r_blk_trace.json
# fileName = ALL.chr7.250000.vcf
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/ALL.chr7.250000.vcf.15921-dc177.local.r_blk_trace.json
# fileName = chr5n-1-201.tar.gz
# fileName = columns.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/columns.txt.65416-dc148.local.r_blk_trace.json
# fileName = ALL.chr5.250000.vcf
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/ALL.chr5.250000.vcf.65416-dc148.local.r_blk_trace.json
# fileName = ALL.chr1.phase3_shapeit2_mvncall_integrated_v5.20130502.sites.annotation.vcf
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/ALL.chr1.phase3_shapeit2_mvncall_integrated_v5.20130502.sites.annotation.vcf.15950-dc026.local.r_blk_trace.json
# fileName = columns.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/columns.txt.16040-dc177.local.r_blk_trace.json
# fileName = ALL.chr7.250000.vcf
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/ALL.chr7.250000.vcf.16040-dc177.local.r_blk_trace.json
# fileName = chr7n-201-401.tar.gz
# fileName = chr1-EAS-freq.tar.gz
# fileName = sifted.SIFT.chr1.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/sifted.SIFT.chr1.txt.17851-dc026.local.r_blk_trace.json
# fileName = chr1n.tar.gz
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/chr1n.tar.gz.17851-dc026.local.r_blk_trace.json
# fileName = columns.txt
# fileName = columns.txt
# fileName = sifted.SIFT.chr8.txt
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/sifted.SIFT.chr8.txt.30123-dc257.local.r_blk_trace.json
# fileName = chr8n.tar.gz
# Detected random write pattern in file: ./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1/chr8n.tar.gz.30123-dc257.local.r_blk_trace.json
# fileName = chr8-EUR-freq.tar.gz
#   operation randomOffset   transferSize  aggregateFilesizeMB numTasks  \
# 0         0            0   81791.000000             0.078002      NaN
# 1         1            1    8191.921474          2421.758036      NaN
# 2         1            1    8191.921474          2421.758036      NaN
# 3         1            1    8191.912230          2421.794365      NaN
# 4         0            0  101056.000000             0.096375      NaN
#
#   parallelism  totalTime numNodesList numNodes tasksPerNode        trMiB  \
# 0         NaN   0.000049          NaN      NaN          NaN  1593.503085
# 1         NaN  19.632952          NaN      NaN          NaN   123.351699
# 2         NaN  19.632952          NaN      NaN          NaN   123.351699
# 3         NaN  19.658824          NaN      NaN          NaN   123.191215
# 4         NaN   0.000050          NaN      NaN          NaN  1917.557288
#
#   storageType opCount taskName      taskPID                fileName stageOrder
# 0           1       1      NaN   6818-dc111  chr2n-2201-2401.tar.gz        NaN
# 1           1  309988      NaN   6818-dc111     ALL.chr2.250000.vcf        NaN
# 2           1  309988      NaN   6818-dc111             columns.txt        NaN
# 3           1  309993      NaN  25051-dc135     ALL.chr3.250000.vcf        NaN
# 4           1       1      NaN  25051-dc135  chr3n-1201-1401.tar.gz        NaN
# df shape: (1810, 17)
# /tmp/ipykernel_320735/1454156516.py:84: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   folder_dfs = folder_dfs._append(wf_df, ignore_index=True)
# /tmp/ipykernel_320735/1454156516.py:92: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   wf_pfs_df = wf_pfs_df._append(get_test_folder_dfs(test_folders,

# %%
wf_pfs_df.shape, wf_pfs_df.columns
# Out:
# ((1810, 17),
#  Index(['operation', 'randomOffset', 'transferSize', 'aggregateFilesizeMB',
#         'numTasks', 'parallelism', 'totalTime', 'numNodesList', 'numNodes',
#         'tasksPerNode', 'trMiB', 'storageType', 'opCount', 'taskName',
#         'taskPID', 'fileName', 'stageOrder'],
#        dtype='object'))

# %%
def match_script_name(tests):
    # Find folders ending with [t1, t2, t3] in the test_folders
    test_folders = glob.glob(f"{tests}/*")
    wf_trial_folders = [folder for folder in test_folders if folder.endswith("t1") or folder.endswith("t2") or folder.endswith("t3")]
    print(f"Trial folders: {wf_trial_folders}")

    pid_input_output_dict = {}

    for trial_folder in wf_trial_folders:
        blk_files = glob.glob(f"{trial_folder}/*_blk_trace.json")
        print(f"len(blk_files) = {len(blk_files)}")
        unique_pids = get_stat_file_pids(blk_files)

        for pid in unique_pids:
            if pid not in pid_input_output_dict:
                pid_input_output_dict[pid] = {
                    "input": [],
                    "output": [],
                    "prevTask": "",
                    "taskName": ""
                }

            # Find the blk_trace_jsons files with the current task_pid
            w_blk_trace_jsons = glob.glob(f"{trial_folder}/*.{pid}.local.w_blk_trace.json")
            r_blk_trace_jsons = glob.glob(f"{trial_folder}/*.{pid}.local.r_blk_trace.json")

            # Replace ".local" with an empty string
            w_blk_trace_jsons = [f.replace(".local", "") for f in w_blk_trace_jsons]
            r_blk_trace_jsons = [f.replace(".local", "") for f in r_blk_trace_jsons]

            # Process write (output) files
            for w_file_path in w_blk_trace_jsons:
                w_file_name_parts = w_file_path.split(".")
                w_file_name = '.'.join(w_file_name_parts[:-3])  # Remove the last 3 extensions
                w_file_basename = os.path.basename(w_file_name)
                pid_input_output_dict[pid]['output'].append(w_file_basename)

            # Process read (input) files
            for r_file_path in r_blk_trace_jsons:
                r_file_name_parts = r_file_path.split(".")
                r_file_name = '.'.join(r_file_name_parts[:-3])  # Remove the last 3 extensions
                r_file_basename = os.path.basename(r_file_name)
                if r_file_basename not in pid_input_output_dict[pid]['input']:
                    pid_input_output_dict[pid]['input'].append(r_file_basename)

    return pid_input_output_dict

def get_wf_pid_script_dict(test_folder):

    all_wf_dict= {}

    for tests in test_folder:
        # # check of test folder starts with seq or par
        # if tests.startswith("seq"):
        #     numTasksWrite = 1
        #     numTasksRead = 1
        # else:
        #     numTasksWrite = 1
        #     numTasksRead = 1

        # io_size_dfs
        wf_dict = match_script_name(f"{exp_data_path}/{tests}")

        # # corr_matrix(wf_df, storageType)
        all_wf_dict.update(wf_dict)
    return all_wf_dict


all_wf_dict = get_wf_pid_script_dict(test_folders)

print(all_wf_dict)
# Out:
# Trial folders: ['./par_6000_10n_PFS_ps300/300_p_10n_PFS_t1']
# len(blk_files) = 1810
# {'13757-dc026': {'input': ['columns.txt', 'ALL.chr1.250000.vcf'], 'output': ['chr1n-1801-2001.tar.gz'], 'prevTask': '', 'taskName': ''}, '13765-dc026': {'input': ['ALL.chr1.250000.vcf', 'columns.txt'], 'output': ['chr1n-5401-5601.tar.gz'], 'prevTask': '', 'taskName': ''}, '13895-dc026': {'input': ['ALL.chr1.250000.vcf', 'columns.txt'], 'output': ['chr1n-1201-1401.tar.gz'], 'prevTask': '', 'taskName': ''}, '13912-dc026': {'input': ['columns.txt', 'ALL.chr1.250000.vcf'], 'output': ['chr1n-2601-2801.tar.gz'], 'prevTask': '', 'taskName': ''}, '13926-dc026': {'input': ['ALL.chr1.250000.vcf', 'columns.txt'], 'output': ['chr1n-2001-2201.tar.gz'], 'prevTask': '', 'taskName': ''}, '13927-dc026': {'input': ['columns.txt', 'ALL.chr1.250000.vcf'], 'output': ['chr1n-1601-1801.tar.gz'], 'prevTask': '', 'taskName': ''}, '13937-dc026': {'input': ['columns.txt', 'ALL.chr1.250000.vcf'], 'output': ['chr1n-4001-4201.tar.gz'], 'prevTask': '', 'taskName': ''}, '13973-dc026': {'input': ['columns.txt', 'ALL.chr1.250000.vcf'], 'output': ['chr1n-5601-5801.tar.gz'], 'prevTask': '', 'taskName': ''}, '13976-dc026': {'input': ['columns.txt', 'ALL.chr1.250000.vcf'], 'output': ['chr1n-4201-4401.tar.gz'], 'prevTask': '', 'taskName': ''}, '14253-dc026': {'input': ['ALL.chr1.250000.vcf', 'columns.txt'], 'output': ['chr1n-2201-2401.tar.gz'], 'prevTask': '', 'taskName': ''}, '14383-dc026': {'input': ['ALL.chr1.250000.vcf', 'columns.txt'], 'output': ['chr1n-4401-4601.tar.gz'], 'prevTask': '', 'taskName': ''}, '14542-dc026': {'input': ['ALL.chr1.250000.vcf', 'columns.txt'], 'output': ['chr1n-5201-5401.tar.gz'], 'prevTask': '', 'taskName': ''}, '14648-dc026': {'input': ['columns.txt', 'ALL.chr1.250000.vcf'], 'output': ['chr1n-5001-5201.tar.gz'], 'prevTask': '', 'taskName': ''}, '14738-dc026': {'input': ['ALL.chr1.250000.vcf', 'columns.txt'], 'output': ['chr1n-1-201.tar.gz'], 'prevTask': '', 'taskName': ''}, '14972-dc026': {'input': ['columns.txt', 'ALL.chr1.250000.vcf'], 'output': ['chr1n-1001-1201.tar.gz'], 'prevTask': '', 'taskName': ''}, '14977-dc026': {'input': ['ALL.chr1.250000.vcf', 'columns.txt'], 'output': ['chr1n-601-801.tar.gz'], 'prevTask': '', 'taskName': ''}, '14980-dc026': {'input': ['columns.txt', 'ALL.chr1.250000.vcf'], 'output': ['chr1n-201-401.tar.gz'], 'prevTask': '', 'taskName': ''}, '14988-dc026': {'input': ['columns.txt', 'ALL.chr1.250000.vcf'], 'output': ['chr1n-3601-3801.tar.gz'], 'prevTask': '', 'taskName': ''}, '14998-dc026': {'input': ['columns.txt', 'ALL.chr1.250000.vcf'], 'output': ['chr1n-2401-2601.tar.gz'], 'prevTask': '', 'taskName': ''}, '15007-dc026': {'input': ['ALL.chr1.250000.vcf', 'columns.txt'], 'output': ['chr1n-5801-6001.tar.gz'], 'prevTask': '', 'taskName': ''}, '15023-dc026': {'input': ['ALL.chr1.250000.vcf', 'columns.txt'], 'output': ['chr1n-2801-3001.tar.gz'], 'prevTask': '', 'taskName': ''}, '15025-dc026': {'input': ['columns.txt', 'ALL.chr1.250000.vcf'], 'output': ['chr1n-401-601.tar.gz'], 'prevTask': '', 'taskName': ''}, '15028-dc026': {'input': ['ALL.chr1.250000.vcf', 'columns.txt'], 'output': ['chr1n-1401-1601.tar.gz'], 'prevTask': '', 'taskName': ''}, '15029-dc026': {'input': ['ALL.chr1.250000.vcf', 'columns.txt'], 'output': ['chr1n-4801-5001.tar.gz'], 'prevTask': '', 'taskName': ''}, '15031-dc026': {'input': ['ALL.chr1.250000.vcf', 'columns.txt'], 'output': ['chr1n-3401-3601.tar.gz'], 'prevTask': '', 'taskName': ''}, '15033-dc026': {'input': ['ALL.chr1.250000.vcf', 'columns.txt'], 'output': ['chr1n-4601-4801.tar.gz'], 'prevTask': '', 'taskName': ''}, '15035-dc026': {'input': ['ALL.chr1.250000.vcf', 'columns.txt'], 'output': ['chr1n-3201-3401.tar.gz'], 'prevTask': '', 'taskName': ''}, '15037-dc026': {'input': ['ALL.chr1.250000.vcf', 'columns.txt'], 'output': ['chr1n-3801-4001.tar.gz'], 'prevTask': '', 'taskName': ''}, '15039-dc026': {'input': ['columns.txt', 'ALL.chr1.250000.vcf'], 'output': ['chr1n-801-1001.tar.gz'], 'prevTask': '', 'taskName': ''}, '15041-dc026': {'input': ['columns.txt', 'ALL.chr1.250000.vcf'], ' ...

# %%
# Add prevTask column
wf_pfs_df['prevTask'] = ""
wf_pfs_df['taskName'] = "unknown"
print(wf_pfs_df.head(5))
print(wf_pfs_df.shape)
# Out:
#   operation randomOffset   transferSize  aggregateFilesizeMB numTasks  \
# 0         0            0   81791.000000             0.078002      NaN
# 1         1            1    8191.921474          2421.758036      NaN
# 2         1            1    8191.921474          2421.758036      NaN
# 3         1            1    8191.912230          2421.794365      NaN
# 4         0            0  101056.000000             0.096375      NaN
#
#   parallelism  totalTime numNodesList numNodes tasksPerNode        trMiB  \
# 0         NaN   0.000049          NaN      NaN          NaN  1593.503085
# 1         NaN  19.632952          NaN      NaN          NaN   123.351699
# 2         NaN  19.632952          NaN      NaN          NaN   123.351699
# 3         NaN  19.658824          NaN      NaN          NaN   123.191215
# 4         NaN   0.000050          NaN      NaN          NaN  1917.557288
#
#   storageType opCount taskName      taskPID                fileName  \
# 0           1       1  unknown   6818-dc111  chr2n-2201-2401.tar.gz
# 1           1  309988  unknown   6818-dc111     ALL.chr2.250000.vcf
# 2           1  309988  unknown   6818-dc111             columns.txt
# 3           1  309993  unknown  25051-dc135     ALL.chr3.250000.vcf
# 4           1       1  unknown  25051-dc135  chr3n-1201-1401.tar.gz
#
#   stageOrder prevTask
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# (1810, 18)

# %%
# save to initial df
wf_pfs_df.to_csv(f'./analyzed_data/first_df.csv', index=False)

# %%
import re
        
def matches_pattern(file_path, patterns):
    """Match a file path against task definition patterns."""
    file_name = os.path.basename(file_path)
    for pattern in patterns:
        try:
            regex_pattern = re.compile(pattern)
            if regex_pattern.fullmatch(file_name):
                return True
        except re.error as e:
            print(f"Invalid regex: {pattern}, Error: {e}")
    return False

def assign_task_names(tasks, task_order_dict):
    """Assign task names and predecessors to tasks based on patterns."""
    for task_pid, details in tasks.items():
        input_paths = details.get('input', [])
        output_paths = details.get('output', [])
        task_name = details.get('taskName', 'unknown')  # Use existing or default to 'unknown'

        # Iterate through each task definition
        for task, definition in task_order_dict.items():
            # Check if any output matches
            if any(matches_pattern(op, definition['outputs']) for op in output_paths):
                task_name = task
                tasks[task_pid]['taskName'] = task_name
                tasks[task_pid]['stage_order'] = definition['stage_order']
                break

            # If no output matches, check for input matches
            for prevTask, predecessor_def in definition['predecessors'].items():
                if any(matches_pattern(ip, predecessor_def.get('inputs', [])) for ip in input_paths):
                    task_name = task
                    tasks[task_pid]['taskName'] = task_name
                    tasks[task_pid]['stage_order'] = definition['stage_order']
                    tasks[task_pid]['prevTask'] = prevTask
                    # print(f"Input match found: Task [{task}] prevTask [{prevTask}] with input_patterns {predecessor_def.get('inputs', [])}")
                    break

        # If no valid match, warn about the task
        if task_name == 'unknown':
            print(f"Warning: Task PID {task_pid} could not be assigned a valid taskName.")

    return tasks
        
# Load task ordering json file
task_order_dict = {}
with open(f"{exp_data_path}/{SCRIPT_ORDER}.json") as f:
    task_order_dict = json.load(f)

print(f"task_order_dict : {task_order_dict}")
# Create a mapping from taskName to parallelism
task_name_to_parallelism = {task: info['parallelism'] for task, info in task_order_dict.items()}
task_name_to_num_tasks = {task: info['num_tasks'] for task, info in task_order_dict.items()}
print(task_name_to_parallelism)
print(task_name_to_num_tasks)

# Fill in task names
assign_task_names(all_wf_dict, task_order_dict)



# Unique list of taskNames
taskNames = set([v['taskName'] for v in all_wf_dict.values()])
print(f"Unique taskNames: {taskNames}")
print(f"all_wf_dict:")
for k,v in all_wf_dict.items():
    print(f"{k}:{v}")
print(f"all_wf_dict-----")

if DEBUG:
    print(wf_pfs_df['fileName'].unique())
    print(wf_pfs_df['taskName'].unique())
# Out:
# task_order_dict : {'individuals': {'stage_order': 1, 'parallelism': 300, 'num_tasks': 300, 'predecessors': {'initial_data': {'inputs': ['ALL\\.chr.*\\.250000\\.vcf', 'columns\\.txt']}}, 'outputs': ['chr.*n-.*-.*\\.tar\\.gz']}, 'individuals_merge': {'stage_order': 2, 'parallelism': 10, 'num_tasks': 10, 'predecessors': {'individuals': {'inputs': ['chr.*n-.*-.*\\.tar\\.gz']}}, 'outputs': ['chr.*n\\.tar\\.gz']}, 'sifting': {'stage_order': 2, 'parallelism': 10, 'num_tasks': 10, 'predecessors': {'initial_data': {'inputs': ['ALL\\.chr([1-9]|10)\\.phase3_shapeit2_mvncall_integrated_v5\\.20130502\\.sites\\.annotation\\.vcf']}}, 'outputs': ['sifted.*\\.txt']}, 'mutation_overlap': {'stage_order': 3, 'parallelism': 10, 'num_tasks': 10, 'predecessors': {'initial_data': {'inputs': ['SAS', 'EAS', 'GBR', 'AMR', 'AFR', 'EUR', 'ALL', 'columns\\.txt']}, 'sifting': {'inputs': ['sifted.*\\.txt']}, 'individuals_merge': {'inputs': ['chr.*n\\.tar\\.gz']}}, 'outputs': ['chr\\d+-[A-Z]{3}\\.tar\\.gz$', 'chr\\d+-[A-Z]{3}\\.txt\\.tar\\.gz$']}, 'frequency': {'stage_order': 3, 'parallelism': 10, 'num_tasks': 10, 'predecessors': {'initial_data': {'inputs': ['SAS', 'EAS', 'GBR', 'AMR', 'AFR', 'EUR', 'ALL', 'columns\\.txt']}, 'individuals_merge': {'inputs': ['chr.*\\.tar\\.gz']}, 'sifting': {'inputs': ['sifted.*\\.txt']}}, 'outputs': ['chr\\d+-[A-Z]{3}\\-freq\\.tar\\.gz$']}}
# {'individuals': 300, 'individuals_merge': 10, 'sifting': 10, 'mutation_overlap': 10, 'frequency': 10}
# {'individuals': 300, 'individuals_merge': 10, 'sifting': 10, 'mutation_overlap': 10, 'frequency': 10}
# Unique taskNames: {'sifting', 'mutation_overlap', 'individuals', 'individuals_merge', 'frequency'}
# all_wf_dict:
# 13757-dc026:{'input': ['columns.txt', 'ALL.chr1.250000.vcf'], 'output': ['chr1n-1801-2001.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 13765-dc026:{'input': ['ALL.chr1.250000.vcf', 'columns.txt'], 'output': ['chr1n-5401-5601.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 13895-dc026:{'input': ['ALL.chr1.250000.vcf', 'columns.txt'], 'output': ['chr1n-1201-1401.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 13912-dc026:{'input': ['columns.txt', 'ALL.chr1.250000.vcf'], 'output': ['chr1n-2601-2801.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 13926-dc026:{'input': ['ALL.chr1.250000.vcf', 'columns.txt'], 'output': ['chr1n-2001-2201.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 13927-dc026:{'input': ['columns.txt', 'ALL.chr1.250000.vcf'], 'output': ['chr1n-1601-1801.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 13937-dc026:{'input': ['columns.txt', 'ALL.chr1.250000.vcf'], 'output': ['chr1n-4001-4201.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 13973-dc026:{'input': ['columns.txt', 'ALL.chr1.250000.vcf'], 'output': ['chr1n-5601-5801.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 13976-dc026:{'input': ['columns.txt', 'ALL.chr1.250000.vcf'], 'output': ['chr1n-4201-4401.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 14253-dc026:{'input': ['ALL.chr1.250000.vcf', 'columns.txt'], 'output': ['chr1n-2201-2401.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 14383-dc026:{'input': ['ALL.chr1.250000.vcf', 'columns.txt'], 'output': ['chr1n-4401-4601.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 14542-dc026:{'input': ['ALL.chr1.250000.vcf', 'columns.txt'], 'output': ['chr1n-5201-5401.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 14648-dc026:{'input': ['columns.txt', 'ALL.chr1.250000.vcf'], 'output': ['chr1n-5001-5201.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 14738-dc026:{'input': ['ALL.chr1.250000.vcf', 'columns.txt'], 'output': ['chr1n-1-201.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 14972-dc026:{'input': ['columns.txt', 'ALL.chr1.250000.vcf'], 'output': ['chr1n-1001-1201.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 14977-dc026:{'input': ['ALL.chr1.250000.vcf', 'columns.txt'], 'output': ['chr1n-601-801.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 14980-dc026:{'input': ['columns.txt', 'ALL.chr1.250000.vcf'], 'output': ['chr1n-201-401.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 14988-dc026:{'input': ['columns.txt', 'ALL.chr1.250000.vcf'], 'output': ['chr1n-3601-3801.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 14998-dc026:{'input': ['columns.txt', 'ALL.chr1.250000.vcf'], 'output': ['chr1n-2401-2601.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 15007-dc026:{'input': ['ALL.chr1.250000.vcf', 'columns.txt'], 'output': ['chr1n-5801-6001.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 15023-dc026:{'input': ['ALL.chr1.250000.vcf', 'columns.txt'], 'output': ['chr1n-2801-3001.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 15025-dc026:{'input': ['columns.txt', 'ALL.chr1.250000.vcf'], 'output': ['chr1n-401-601.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 15028-dc026:{'input': ['ALL.chr1.250000.vcf', 'columns.txt'], 'output': ['chr1n-1401-1601.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 15029-dc026:{'input': ['ALL.chr1.250000.vcf', 'columns.txt'], 'output': ['chr1n-4801-5001.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 15031-dc026:{'input': ['ALL.chr1.250000.vcf', 'columns.txt'], 'output': ['chr1n-3401-3601.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 15033-dc026:{'input': ['ALL.chr1.250000.vcf', 'columns.txt'], 'output': ['chr1n-4601-4801.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 15035-dc026:{'input': ['ALL.chr1.250000.vcf', 'columns.txt'], 'output': ['chr1n-3201-3401.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 15037-dc026:{'input': ['ALL.chr1.250000.vcf', 'columns.txt'], 'output': ['chr1n-3801-4001.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 15039-dc026:{'input': ['columns.txt', 'ALL.chr1.250000.vcf'], 'output': ['chr1n-801-1001.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 15041-dc026:{'input': ['columns.txt', 'ALL.chr1.250000.vcf'], 'output': ['chr1n-3001-3201.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 15816-dc177:{'input': ['columns.txt', 'ALL.chr7.250000.vcf'], 'output': ['chr7n-1801-2001.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 15818-dc177:{'input': ['ALL.chr7.250000.vcf', 'columns.txt'], 'output': ['chr7n-4401-4601.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 15820-dc177:{'input': ['ALL.chr7.250000.vcf', 'columns.txt'], 'output': ['chr7n-3801-4001.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 15873-dc177:{'input': ['columns.txt', 'ALL.chr7.250000.vcf'], 'output': ['chr7n-1401-1601.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 15876-dc177:{'input': ['columns.txt', 'ALL.chr7.250000.vcf'], 'output': ['chr7n-2401-2601.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 15918-dc026:{'input': ['chr1n-2801-3001.tar.gz', 'chr1n-3201-3401.tar.gz', 'chr1n-1001-1201.tar.gz', 'chr1n-3401-3601.tar.gz', 'chr1n-5001-5201.tar.gz', 'chr1n-201-401.tar.gz', 'chr1n-4401-4601.tar.gz', 'chr1n-1801-2001.tar.gz', 'chr1n-2201-2401.tar.gz', 'chr1n-2601-2801.tar.gz', 'chr1n-5801-6001.tar.gz', 'chr1n-4201-4401.tar.gz', 'chr1n-3601-3801.tar.gz', 'chr1n-601-801.tar.gz', 'chr1n-2001-2201.tar.gz', 'chr1n-1-201.tar.gz', 'chr1n-401-601.tar.gz', 'chr1n-4001-4201.tar.gz', 'chr1n-4601-4801.tar.gz', 'chr1n-4801-5001.tar.gz', 'chr1n-801-1001.tar.gz', 'chr1n-5601-5801.tar.gz', 'chr1n-3801-4001.tar.gz', 'chr1n-1401-1601.tar.gz', 'chr1n-2401-2601.tar.gz', 'chr1n-1201-1401.tar.gz', 'chr1n-5401-5601.tar.gz', 'chr1n-1601-1801.tar.gz', 'chr1n-5201-5401.tar.gz', 'chr1n-3001-3201.tar.gz'], 'output': ['chr1n.tar.gz'], 'prevTask': '', 'taskName': 'individuals_merge', 'stage_order': 2}
# 15919-dc026:{'input': ['ALL.chr1.phase3_shapeit2_mvncall_integrated_v5.20130502.sites.annotation.vcf', 'SIFT.chr1.vcf'], 'output': ['sifted.SIFT.chr1.txt'], 'prevTask': '', 'taskName': 'sifting', 'stage_order': 2}
# 15921-dc177:{'input': ['columns.txt', 'ALL.chr7.250000.vcf'], 'output': ['chr7n-5601-5801.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 15948-dc177:{'input': ['columns.txt', 'ALL.chr7.250000.vcf'], 'output': ['chr7n-1601-1801.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 15950-dc026:{'input': ['ALL.chr1.phase3_shapeit2_mvncall_integrated_v5.20130502.sites.annotation.vcf'], 'output': [], 'prevTask': 'initial_data', 'taskName': 'sifting', 'stage_order': 2}
# 15980-dc177:{'input': ['columns.txt', 'ALL.chr7.250000.vcf'], 'output': ['chr7n-3201-3401.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 15985-dc177:{'input': ['ALL.chr7.250000.vcf', 'columns.txt'], 'output': ['chr7n-3601-3801.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 15987-dc177:{'input': ['columns.txt', 'ALL.chr7.250000.vcf'], 'output': ['chr7n-801-1001.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 15989-dc177:{'input': ['ALL.chr7.250000.vcf', 'columns.txt'], 'output': ['chr7n-401-601.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 15991-dc177:{'input': ['columns.txt', 'ALL.chr7.250000.vcf'], 'output': ['chr7n-5801-6001.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 15993-dc177:{'input': ['ALL.chr7.250000.vcf', 'columns.txt'], 'output': ['chr7n-2801-3001.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 15995-dc177:{'input': ['columns.txt', 'ALL.chr7.250000.vcf'], 'output': ['chr7n-4201-4401.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 15997-dc177:{'input': ['columns.txt', 'ALL.chr7.250000.vcf'], 'output': ['chr7n-5201-5401.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 15999-dc177:{'input': ['columns.txt', 'ALL.chr7.250000.vcf'], 'output': ['chr7n-4801-5001.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 16001-dc177:{'input': ['columns.txt', 'ALL.chr7.250000.vcf'], 'output': ['chr7n-4601-4801.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 16003-dc177:{'input': ['ALL.chr7.250000.vcf', 'columns.txt'], 'output': ['chr7n-601-801.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 16005-dc177:{'input': ['columns.txt', 'ALL.chr7.250000.vcf'], 'output': ['chr7n-4001-4201.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 16008-dc177:{'input': ['columns.txt', 'ALL.chr7.250000.vcf'], 'output': ['chr7n-5401-5601.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 16009-dc177:{'input': ['ALL.chr7.250000.vcf', 'columns.txt'], 'output': ['chr7n-5001-5201.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 16011-dc177:{'input': ['ALL.chr7.250000.vcf', 'columns.txt'], 'output': ['chr7n-1001-1201.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 16013-dc177:{'input': ['ALL.chr7.250000.vcf', 'columns.txt'], 'output': ['chr7n-2201-2401.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 16015-dc177:{'input': ['ALL.chr7.250000.vcf', 'columns.txt'], 'output': ['chr7n-3401-3601.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 16017-dc177:{'input': ['ALL.chr7.250000.vcf', 'columns.txt'], 'output': ['chr7n-2601-2801.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 16019-dc177:{'input': ['ALL.chr7.250000.vcf', 'columns.txt'], 'output': ['chr7n-1201-1401.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 16021-dc177:{'input': ['columns.txt', 'ALL.chr7.250000.vcf'], 'output': ['chr7n-3001-3201.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 16023-dc177:{'input': ['columns.txt', 'ALL.chr7.250000.vcf'], 'output': ['chr7n-1-201.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 16032-dc177:{'input': ['ALL.chr7.250000.vcf', 'columns.txt'], 'output': ['chr7n-2001-2201.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 16040-dc177:{'input': ['columns.txt', 'ALL.chr7.250000.vcf'], 'output': ['chr7n-201-401.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 16490-dc177:{'input': ['chr7n-5401-5601.tar.gz', 'chr7n-3401-3601.tar.gz', 'chr7n-2401-2601.tar.gz', 'chr7n-2601-2801.tar.gz', 'chr7n-601-801.tar.gz', 'chr7n-3601-3801.tar.gz', 'chr7n-201-401.tar.gz', 'chr7n-5801-6001.tar.gz', 'chr7n-1601-1801.tar.gz', 'chr7n-1-201.tar.gz', 'chr7n-401-601.tar.gz', 'chr7n-801-1001.tar.gz', 'chr7n-1201-1401.tar.gz', 'chr7n-5001-5201.tar.gz', 'chr7n-5201-5401.tar.gz', 'chr7n-3001-3201.tar.gz', 'chr7n-2801-3001.tar.gz', 'chr7n-5601-5801.tar.gz', 'chr7n-3801-4001.tar.gz', 'chr7n-4801-5001.tar.gz', 'chr7n-4201-4401.tar.gz', 'chr7n-1001-1201.tar.gz', 'chr7n-4601-4801.tar.gz', 'chr7n-3201-3401.tar.gz', 'chr7n-1401-1601.tar.gz', 'chr7n-4001-4201.tar.gz', 'chr7n-2201-2401.tar.gz', 'chr7n-2001-2201.tar.gz', 'chr7n-1801-2001.tar.gz', 'chr7n-4401-4601.tar.gz'], 'output': ['chr7n.tar.gz'], 'prevTask': '', 'taskName': 'individuals_merge', 'stage_order': 2}
# 16492-dc177:{'input': ['ALL.chr7.phase3_shapeit2_mvncall_integrated_v5.20130502.sites.annotation.vcf', 'SIFT.chr7.vcf'], 'output': ['sifted.SIFT.chr7.txt'], 'prevTask': '', 'taskName': 'sifting', 'stage_order': 2}
# 16503-dc177:{'input': ['ALL.chr7.phase3_shapeit2_mvncall_integrated_v5.20130502.sites.annotation.vcf'], 'output': [], 'prevTask': 'initial_data', 'taskName': 'sifting', 'stage_order': 2}
# 17508-dc177:{'input': ['sifted.SIFT.chr7.txt', 'chr7n.tar.gz', 'columns.txt'], 'output': ['chr7-GBR.tar.gz'], 'prevTask': 'initial_data', 'taskName': 'mutation_overlap', 'stage_order': 3}
# 17520-dc177:{'input': ['columns.txt', 'chr7n.tar.gz', 'sifted.SIFT.chr7.txt'], 'output': ['chr7-EAS.tar.gz'], 'prevTask': 'initial_data', 'taskName': 'mutation_overlap', 'stage_order': 3}
# 17526-dc026:{'input': ['chr1n.tar.gz', 'columns.txt', 'sifted.SIFT.chr1.txt'], 'output': ['chr1-GBR.tar.gz'], 'prevTask': 'initial_data', 'taskName': 'mutation_overlap', 'stage_order': 3}
# 17538-dc177:{'input': ['columns.txt', 'chr7n.tar.gz', 'sifted.SIFT.chr7.txt'], 'output': ['chr7-AMR.tar.gz'], 'prevTask': 'initial_data', 'taskName': 'mutation_overlap', 'stage_order': 3}
# 17546-dc026:{'input': ['sifted.SIFT.chr1.txt', 'columns.txt', 'chr1n.tar.gz'], 'output': ['chr1-ALL.tar.gz'], 'prevTask': 'initial_data', 'taskName': 'mutation_overlap', 'stage_order': 3}
# 17556-dc177:{'input': ['columns.txt', 'chr7n.tar.gz', 'sifted.SIFT.chr7.txt'], 'output': ['chr7-ALL.tar.gz'], 'prevTask': 'initial_data', 'taskName': 'mutation_overlap', 'stage_order': 3}
# 17559-dc177:{'input': ['columns.txt', 'sifted.SIFT.chr7.txt', 'chr7n.tar.gz'], 'output': ['chr7-EAS-freq.tar.gz'], 'prevTask': 'initial_data', 'taskName': 'frequency', 'stage_order': 3}
# 17561-dc177:{'input': ['sifted.SIFT.chr7.txt', 'chr7n.tar.gz', 'columns.txt'], 'output': ['chr7-AFR-freq.tar.gz'], 'prevTask': 'initial_data', 'taskName': 'frequency', 'stage_order': 3}
# 17563-dc177:{'input': ['sifted.SIFT.chr7.txt', 'columns.txt', 'chr7n.tar.gz'], 'output': ['chr7-SAS-freq.tar.gz'], 'prevTask': 'initial_data', 'taskName': 'frequency', 'stage_order': 3}
# 17565-dc177:{'input': ['chr7n.tar.gz', 'columns.txt', 'sifted.SIFT.chr7.txt'], 'output': ['chr7-EUR-freq.tar.gz'], 'prevTask': 'initial_data', 'taskName': 'frequency', 'stage_order': 3}
# 17567-dc177:{'input': ['chr7n.tar.gz', 'sifted.SIFT.chr7.txt', 'columns.txt'], 'output': ['chr7-AFR.tar.gz'], 'prevTask': 'initial_data', 'taskName': 'mutation_overlap', 'stage_order': 3}
# 17570-dc177:{'input': ['columns.txt', 'sifted.SIFT.chr7.txt', 'chr7n.tar.gz'], 'output': ['chr7-AMR-freq.tar.gz'], 'prevTask': 'initial_data', 'taskName': 'frequency', 'stage_order': 3}
# 17571-dc177:{'input': ['chr7n.tar.gz', 'columns.txt', 'sifted.SIFT.chr7.txt'], 'output': ['chr7-EUR.tar.gz'], 'prevTask': 'initial_data', 'taskName': 'mutation_overlap', 'stage_order': 3}
# 17573-dc177:{'input': ['columns.txt', 'chr7n.tar.gz', 'sifted.SIFT.chr7.txt'], 'output': ['chr7-GBR-freq.tar.gz'], 'prevTask': 'initial_data', 'taskName': 'frequency', 'stage_order': 3}
# 17576-dc177:{'input': ['columns.txt', 'chr7n.tar.gz', 'sifted.SIFT.chr7.txt'], 'output': ['chr7-ALL-freq.tar.gz'], 'prevTask': 'initial_data', 'taskName': 'frequency', 'stage_order': 3}
# 17578-dc177:{'input': ['columns.txt', 'sifted.SIFT.chr7.txt', 'chr7n.tar.gz'], 'output': ['chr7-SAS.tar.gz'], 'prevTask': 'initial_data', 'taskName': 'mutation_overlap', 'stage_order': 3}
# 17652-dc026:{'input': ['columns.txt', 'sifted.SIFT.chr1.txt', 'chr1n.tar.gz'], 'output': ['chr1-EAS.tar.gz'], 'prevTask': 'initial_data', 'taskName': 'mutation_overlap', 'stage_order': 3}
# 17781-dc026:{'input': ['sifted.SIFT.chr1.txt', 'columns.txt', 'chr1n.tar.gz'], 'output': ['chr1-SAS.tar.gz'], 'prevTask': 'initial_data', 'taskName': 'mutation_overlap', 'stage_order': 3}
# 17782-dc026:{'input': ['chr1n.tar.gz', 'columns.txt', 'sifted.SIFT.chr1.txt'], 'output': ['chr1-EUR.tar.gz'], 'prevTask': 'initial_data', 'taskName': 'mutation_overlap', 'stage_order': 3}
# 17786-dc026:{'input': ['chr1n.tar.gz', 'sifted.SIFT.chr1.txt', 'columns.txt'], 'output': ['chr1-SAS-freq.tar.gz'], 'prevTask': 'initial_data', 'taskName': 'frequency', 'stage_order': 3}
# 17851-dc026:{'input': ['sifted.SIFT.chr1.txt', 'chr1n.tar.gz', 'columns.txt'], 'output': ['chr1-EAS-freq.tar.gz'], 'prevTask': 'initial_data', 'taskName': 'frequency', 'stage_order': 3}
# 17869-dc026:{'input': ['sifted.SIFT.chr1.txt', 'columns.txt', 'chr1n.tar.gz'], 'output': ['chr1-AFR.tar.gz'], 'prevTask': 'initial_data', 'taskName': 'mutation_overlap', 'stage_order': 3}
# 17870-dc026:{'input': ['sifted.SIFT.chr1.txt', 'chr1n.tar.gz', 'columns.txt'], 'output': ['chr1-AFR-freq.tar.gz'], 'prevTask': 'initial_data', 'taskName': 'frequency', 'stage_order': 3}
# 17872-dc026:{'input': ['sifted.SIFT.chr1.txt', 'chr1n.tar.gz', 'columns.txt'], 'output': ['chr1-AMR.tar.gz'], 'prevTask': 'initial_data', 'taskName': 'mutation_overlap', 'stage_order': 3}
# 17874-dc026:{'input': ['sifted.SIFT.chr1.txt', 'chr1n.tar.gz', 'columns.txt'], 'output': ['chr1-GBR-freq.tar.gz'], 'prevTask': 'initial_data', 'taskName': 'frequency', 'stage_order': 3}
# 17876-dc026:{'input': ['sifted.SIFT.chr1.txt', 'columns.txt', 'chr1n.tar.gz'], 'output': ['chr1-EUR-freq.tar.gz'], 'prevTask': 'initial_data', 'taskName': 'frequency', 'stage_order': 3}
# 17878-dc026:{'input': ['columns.txt', 'sifted.SIFT.chr1.txt', 'chr1n.tar.gz'], 'output': ['chr1-ALL-freq.tar.gz'], 'prevTask': 'initial_data', 'taskName': 'frequency', 'stage_order': 3}
# 17880-dc026:{'input': ['chr1n.tar.gz', 'columns.txt', 'sifted.SIFT.chr1.txt'], 'output': ['chr1-AMR-freq.tar.gz'], 'prevTask': 'initial_data', 'taskName': 'frequency', 'stage_order': 3}
# 1900-dc148:{'input': ['columns.txt', 'sifted.SIFT.chr5.txt', 'chr5n.tar.gz'], 'output': ['chr5-EAS.tar.gz'], 'prevTask': 'initial_data', 'taskName': 'mutation_overlap', 'stage_order': 3}
# 1903-dc148:{'input': ['sifted.SIFT.chr5.txt', 'chr5n.tar.gz', 'columns.txt'], 'output': ['chr5-AMR.tar.gz'], 'prevTask': 'initial_data', 'taskName': 'mutation_overlap', 'stage_order': 3}
# 1906-dc148:{'input': ['columns.txt', 'sifted.SIFT.chr5.txt', 'chr5n.tar.gz'], 'output': ['chr5-ALL.tar.gz'], 'prevTask': 'initial_data', 'taskName': 'mutation_overlap', 'stage_order': 3}
# 1909-dc148:{'input': ['columns.txt', 'chr5n.tar.gz', 'sifted.SIFT.chr5.txt'], 'output': ['chr5-EUR.tar.gz'], 'prevTask': 'initial_data', 'taskName': 'mutation_overlap', 'stage_order': 3}
# 1940-dc148:{'input': ['sifted.SIFT.chr5.txt', 'chr5n.tar.gz', 'columns.txt'], 'output': ['chr5-ALL-freq.tar.gz'], 'prevTask': 'initial_data', 'taskName': 'frequency', 'stage_order': 3}
# 194433-dc273:{'input': ['ALL.chr10.250000.vcf', 'columns.txt'], 'output': ['chr10n-5601-5801.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 194452-dc273:{'input': ['ALL.chr10.250000.vcf', 'columns.txt'], 'output': ['chr10n-3401-3601.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 194456-dc273:{'input': ['columns.txt', 'ALL.chr10.250000.vcf'], 'output': ['chr10n-4401-4601.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 194457-dc273:{'input': ['ALL.chr10.250000.vcf', 'columns.txt'], 'output': ['chr10n-4001-4201.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 194458-dc273:{'input': ['ALL.chr10.250000.vcf', 'columns.txt'], 'output': ['chr10n-2201-2401.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 194525-dc273:{'input': ['columns.txt', 'ALL.chr10.250000.vcf'], 'output': ['chr10n-2601-2801.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 194557-dc273:{'input': ['ALL.chr10.250000.vcf', 'columns.txt'], 'output': ['chr10n-1-201.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 194563-dc273:{'input': ['columns.txt', 'ALL.chr10.250000.vcf'], 'output': ['chr10n-5201-5401.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 194576-dc273:{'input': ['ALL.chr10.250000.vcf', 'columns.txt'], 'output': ['chr10n-2801-3001.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 194583-dc273:{'input': ['ALL.chr10.250000.vcf', 'columns.txt'], 'output': ['chr10n-201-401.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 194623-dc273:{'input': ['ALL.chr10.250000.vcf', 'columns.txt'], 'output': ['chr10n-1001-1201.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 194625-dc273:{'input': ['ALL.chr10.250000.vcf', 'columns.txt'], 'output': ['chr10n-401-601.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 194627-dc273:{'input': ['ALL.chr10.250000.vcf', 'columns.txt'], 'output': ['chr10n-1801-2001.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 194629-dc273:{'input': ['columns.txt', 'ALL.chr10.250000.vcf'], 'output': ['chr10n-1601-1801.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 194631-dc273:{'input': ['columns.txt', 'ALL.chr10.250000.vcf'], 'output': ['chr10n-2401-2601.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 194633-dc273:{'input': ['ALL.chr10.250000.vcf', 'columns.txt'], 'output': ['chr10n-801-1001.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 194635-dc273:{'input': ['ALL.chr10.250000.vcf', 'columns.txt'], 'output': ['chr10n-3001-3201.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 194637-dc273:{'input': ['columns.txt', 'ALL.chr10.250000.vcf'], 'output': ['chr10n-3601-3801.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 194639-dc273:{'input': ['ALL.chr10.250000.vcf', 'columns.txt'], 'output': ['chr10n-3201-3401.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 194641-dc273:{'input': ['columns.txt', 'ALL.chr10.250000.vcf'], 'output': ['chr10n-1201-1401.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 194643-dc273:{'input': ['columns.txt', 'ALL.chr10.250000.vcf'], 'output': ['chr10n-4801-5001.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 194645-dc273:{'input': ['columns.txt', 'ALL.chr10.250000.vcf'], 'output': ['chr10n-3801-4001.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 194647-dc273:{'input': ['ALL.chr10.250000.vcf', 'columns.txt'], 'output': ['chr10n-5801-6001.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 194649-dc273:{'input': ['columns.txt', 'ALL.chr10.250000.vcf'], 'output': ['chr10n-601-801.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 194651-dc273:{'input': ['columns.txt', 'ALL.chr10.250000.vcf'], 'output': ['chr10n-5401-5601.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 194653-dc273:{'input': ['columns.txt', 'ALL.chr10.250000.vcf'], 'output': ['chr10n-1401-1601.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 194655-dc273:{'input': ['ALL.chr10.250000.vcf', 'columns.txt'], 'output': ['chr10n-4201-4401.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 194657-dc273:{'input': ['columns.txt', 'ALL.chr10.250000.vcf'], 'output': ['chr10n-2001-2201.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 194660-dc273:{'input': ['ALL.chr10.250000.vcf', 'columns.txt'], 'output': ['chr10n-5001-5201.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 194661-dc273:{'input': ['columns.txt', 'ALL.chr10.250000.vcf'], 'output': ['chr10n-4601-4801.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 194914-dc260:{'input': ['ALL.chr9.250000.vcf', 'columns.txt'], 'output': ['chr9n-5801-6001.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 194924-dc260:{'input': ['columns.txt', 'ALL.chr9.250000.vcf'], 'output': ['chr9n-4601-4801.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 194926-dc260:{'input': ['columns.txt', 'ALL.chr9.250000.vcf'], 'output': ['chr9n-5001-5201.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 194928-dc260:{'input': ['columns.txt', 'ALL.chr9.250000.vcf'], 'output': ['chr9n-5401-5601.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 194930-dc260:{'input': ['ALL.chr9.250000.vcf', 'columns.txt'], 'output': ['chr9n-201-401.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 194932-dc260:{'input': ['ALL.chr9.250000.vcf', 'columns.txt'], 'output': ['chr9n-1801-2001.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 194934-dc260:{'input': ['ALL.chr9.250000.vcf', 'columns.txt'], 'output': ['chr9n-4401-4601.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 195006-dc260:{'input': ['ALL.chr9.250000.vcf', 'columns.txt'], 'output': ['chr9n-1-201.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 195023-dc260:{'input': ['ALL.chr9.250000.vcf', 'columns.txt'], 'output': ['chr9n-1001-1201.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 195030-dc260:{'input': ['columns.txt', 'ALL.chr9.250000.vcf'], 'output': ['chr9n-2801-3001.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 195053-dc260:{'input': ['columns.txt', 'ALL.chr9.250000.vcf'], 'output': ['chr9n-5201-5401.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 195083-dc260:{'input': ['ALL.chr9.250000.vcf', 'columns.txt'], 'output': ['chr9n-1601-1801.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 195086-dc260:{'input': ['columns.txt', 'ALL.chr9.250000.vcf'], 'output': ['chr9n-2001-2201.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 195088-dc260:{'input': ['ALL.chr9.250000.vcf', 'columns.txt'], 'output': ['chr9n-1201-1401.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 195090-dc260:{'input': ['ALL.chr9.250000.vcf', 'columns.txt'], 'output': ['chr9n-2601-2801.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 195092-dc260:{'input': ['ALL.chr9.250000.vcf', 'columns.txt'], 'output': ['chr9n-3401-3601.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 195094-dc260:{'input': ['columns.txt', 'ALL.chr9.250000.vcf'], 'output': ['chr9n-4801-5001.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 195097-dc260:{'input': ['columns.txt', 'ALL.chr9.250000.vcf'], 'output': ['chr9n-5601-5801.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 195099-dc260:{'input': ['columns.txt', 'ALL.chr9.250000.vcf'], 'output': ['chr9n-2201-2401.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 195101-dc260:{'input': ['columns.txt', 'ALL.chr9.250000.vcf'], 'output': ['chr9n-1401-1601.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 195103-dc260:{'input': ['ALL.chr9.250000.vcf', 'columns.txt'], 'output': ['chr9n-801-1001.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 195105-dc260:{'input': ['ALL.chr9.250000.vcf', 'columns.txt'], 'output': ['chr9n-601-801.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 195107-dc260:{'input': ['ALL.chr9.250000.vcf', 'columns.txt'], 'output': ['chr9n-2401-2601.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 195109-dc260:{'input': ['ALL.chr9.250000.vcf', 'columns.txt'], 'output': ['chr9n-3801-4001.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 195109-dc273:{'input': ['ALL.chr10.phase3_shapeit2_mvncall_integrated_v5.20130502.sites.annotation.vcf', 'SIFT.chr10.vcf'], 'output': ['sifted.SIFT.chr10.txt'], 'prevTask': '', 'taskName': 'sifting', 'stage_order': 2}
# 195111-dc260:{'input': ['ALL.chr9.250000.vcf', 'columns.txt'], 'output': ['chr9n-3601-3801.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 195111-dc273:{'input': ['chr10n-3401-3601.tar.gz', 'chr10n-3001-3201.tar.gz', 'chr10n-1801-2001.tar.gz', 'chr10n-4201-4401.tar.gz', 'chr10n-201-401.tar.gz', 'chr10n-4001-4201.tar.gz', 'chr10n-5801-6001.tar.gz', 'chr10n-1201-1401.tar.gz', 'chr10n-4401-4601.tar.gz', 'chr10n-2201-2401.tar.gz', 'chr10n-1001-1201.tar.gz', 'chr10n-1-201.tar.gz', 'chr10n-3801-4001.tar.gz', 'chr10n-5401-5601.tar.gz', 'chr10n-5001-5201.tar.gz', 'chr10n-1401-1601.tar.gz', 'chr10n-1601-1801.tar.gz', 'chr10n-3601-3801.tar.gz', 'chr10n-401-601.tar.gz', 'chr10n-5201-5401.tar.gz', 'chr10n-3201-3401.tar.gz', 'chr10n-5601-5801.tar.gz', 'chr10n-601-801.tar.gz', 'chr10n-2401-2601.tar.gz', 'chr10n-801-1001.tar.gz', 'chr10n-4801-5001.tar.gz', 'chr10n-2001-2201.tar.gz', 'chr10n-4601-4801.tar.gz', 'chr10n-2801-3001.tar.gz', 'chr10n-2601-2801.tar.gz'], 'output': ['chr10n.tar.gz'], 'prevTask': '', 'taskName': 'individuals_merge', 'stage_order': 2}
# 195113-dc260:{'input': ['columns.txt', 'ALL.chr9.250000.vcf'], 'output': ['chr9n-3001-3201.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 195115-dc260:{'input': ['columns.txt', 'ALL.chr9.250000.vcf'], 'output': ['chr9n-401-601.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 195117-dc260:{'input': ['ALL.chr9.250000.vcf', 'columns.txt'], 'output': ['chr9n-4001-4201.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 195119-dc260:{'input': ['ALL.chr9.250000.vcf', 'columns.txt'], 'output': ['chr9n-4201-4401.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 195121-dc260:{'input': ['ALL.chr9.250000.vcf', 'columns.txt'], 'output': ['chr9n-3201-3401.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 195129-dc273:{'input': ['ALL.chr10.phase3_shapeit2_mvncall_integrated_v5.20130502.sites.annotation.vcf'], 'output': [], 'prevTask': 'initial_data', 'taskName': 'sifting', 'stage_order': 2}
# 195581-dc260:{'input': ['ALL.chr9.phase3_shapeit2_mvncall_integrated_v5.20130502.sites.annotation.vcf', 'SIFT.chr9.vcf'], 'output': ['sifted.SIFT.chr9.txt'], 'prevTask': '', 'taskName': 'sifting', 'stage_order': 2}
# 195582-dc260:{'input': ['chr9n-5401-5601.tar.gz', 'chr9n-1801-2001.tar.gz', 'chr9n-4801-5001.tar.gz', 'chr9n-401-601.tar.gz', 'chr9n-3801-4001.tar.gz', 'chr9n-3201-3401.tar.gz', 'chr9n-2801-3001.tar.gz', 'chr9n-1001-1201.tar.gz', 'chr9n-201-401.tar.gz', 'chr9n-4601-4801.tar.gz', 'chr9n-2401-2601.tar.gz', 'chr9n-5001-5201.tar.gz', 'chr9n-4201-4401.tar.gz', 'chr9n-2001-2201.tar.gz', 'chr9n-3601-3801.tar.gz', 'chr9n-4001-4201.tar.gz', 'chr9n-1401-1601.tar.gz', 'chr9n-801-1001.tar.gz', 'chr9n-4401-4601.tar.gz', 'chr9n-601-801.tar.gz', 'chr9n-1201-1401.tar.gz', 'chr9n-3001-3201.tar.gz', 'chr9n-1601-1801.tar.gz', 'chr9n-2201-2401.tar.gz', 'chr9n-5801-6001.tar.gz', 'chr9n-2601-2801.tar.gz', 'chr9n-5201-5401.tar.gz', 'chr9n-3401-3601.tar.gz', 'chr9n-1-201.tar.gz', 'chr9n-5601-5801.tar.gz'], 'output': ['chr9n.tar.gz'], 'prevTask': '', 'taskName': 'individuals_merge', 'stage_order': 2}
# 195591-dc260:{'input': ['ALL.chr9.phase3_shapeit2_mvncall_integrated_v5.20130502.sites.annotation.vcf'], 'output': [], 'prevTask': 'initial_data', 'taskName': 'sifting', 'stage_order': 2}
# 1958-dc148:{'input': ['columns.txt', 'sifted.SIFT.chr5.txt', 'chr5n.tar.gz'], 'output': ['chr5-EAS-freq.tar.gz'], 'prevTask': 'initial_data', 'taskName': 'frequency', 'stage_order': 3}
# 196116-dc273:{'input': ['chr10n.tar.gz', 'columns.txt', 'sifted.SIFT.chr10.txt'], 'output': ['chr10-GBR.tar.gz'], 'prevTask': 'initial_data', 'taskName': 'mutation_overlap', 'stage_order': 3}
# 196118-dc273:{'input': ['chr10n.tar.gz', 'columns.txt', 'sifted.SIFT.chr10.txt'], 'output': ['chr10-AMR.tar.gz'], 'prevTask': 'initial_data', 'taskName': 'mutation_overlap', 'stage_order': 3}
# 196135-dc273:{'input': ['sifted.SIFT.chr10.txt', 'columns.txt', 'chr10n.tar.gz'], 'output': ['chr10-EUR.tar.gz'], 'prevTask': 'initial_data', 'taskName': 'mutation_overlap', 'stage_order': 3}
# 196142-dc273:{'input': ['chr10n.tar.gz', 'sifted.SIFT.chr10.txt', 'columns.txt'], 'output': ['chr10-GBR-freq.tar.gz'], 'prevTask': 'initial_data', 'taskName': 'frequency', 'stage_order': 3}
# 196149-dc273:{'input': ['chr10n.tar.gz', 'sifted.SIFT.chr10.txt', 'columns.txt'], 'output': ['chr10-EAS.tar.gz'], 'prevTask': 'initial_data', 'taskName': 'mutation_overlap', 'stage_order': 3}
# 196152-dc273:{'input': ['chr10n.tar.gz', 'columns.txt', 'sifted.SIFT.chr10.txt'], 'output': ['chr10-SAS.tar.gz'], 'prevTask': 'initial_data', 'taskName': 'mutation_overlap', 'stage_order': 3}
# 196166-dc273:{'input': ['chr10n.tar.gz', 'sifted.SIFT.chr10.txt', 'columns.txt'], 'output': ['chr10-EUR-freq.tar.gz'], 'prevTask': 'initial_data', 'taskName': 'frequency', 'stage_order': 3}
# 196173-dc273:{'input': ['sifted.SIFT.chr10.txt', 'chr10n.tar.gz', 'columns.txt'], 'output': ['chr10-EAS-freq.tar.gz'], 'prevTask': 'initial_data', 'taskName': 'frequency', 'stage_order': 3}
# 196183-dc273:{'input': ['sifted.SIFT.chr10.txt', 'chr10n.tar.gz', 'columns.txt'], 'output': ['chr10-SAS-freq.tar.gz'], 'prevTask': 'initial_data', 'taskName': 'frequency', 'stage_order': 3}
# 196185-dc273:{'input': ['columns.txt', 'chr10n.tar.gz', 'sifted.SIFT.chr10.txt'], 'output': ['chr10-AMR-freq.tar.gz'], 'prevTask': 'initial_data', 'taskName': 'frequency', 'stage_order': 3}
# 196187-dc273:{'input': ['sifted.SIFT.chr10.txt', 'chr10n.tar.gz', 'columns.txt'], 'output': ['chr10-ALL-freq.tar.gz'], 'prevTask': 'initial_data', 'taskName': 'frequency', 'stage_order': 3}
# 196189-dc273:{'input': ['chr10n.tar.gz', 'columns.txt', 'sifted.SIFT.chr10.txt'], 'output': ['chr10-AFR.tar.gz'], 'prevTask': 'initial_data', 'taskName': 'mutation_overlap', 'stage_order': 3}
# 196191-dc273:{'input': ['columns.txt', 'sifted.SIFT.chr10.txt', 'chr10n.tar.gz'], 'output': ['chr10-AFR-freq.tar.gz'], 'prevTask': 'initial_data', 'taskName': 'frequency', 'stage_order': 3}
# 196193-dc273:{'input': ['chr10n.tar.gz', 'columns.txt', 'sifted.SIFT.chr10.txt'], 'output': ['chr10-ALL.tar.gz'], 'prevTask': 'initial_data', 'taskName': 'mutation_overlap', 'stage_order': 3}
# 1963-dc148:{'input': ['columns.txt', 'sifted.SIFT.chr5.txt', 'chr5n.tar.gz'], 'output': ['chr5-GBR-freq.tar.gz'], 'prevTask': 'initial_data', 'taskName': 'frequency', 'stage_order': 3}
# 1965-dc148:{'input': ['chr5n.tar.gz', 'sifted.SIFT.chr5.txt', 'columns.txt'], 'output': ['chr5-AFR-freq.tar.gz'], 'prevTask': 'initial_data', 'taskName': 'frequency', 'stage_order': 3}
# 196580-dc260:{'input': ['chr9n.tar.gz', 'columns.txt', 'sifted.SIFT.chr9.txt'], 'output': ['chr9-SAS.tar.gz'], 'prevTask': 'initial_data', 'taskName': 'mutation_overlap', 'stage_order': 3}
# 196591-dc260:{'input': ['sifted.SIFT.chr9.txt', 'chr9n.tar.gz', 'columns.txt'], 'output': ['chr9-EUR.tar.gz'], 'prevTask': 'initial_data', 'taskName': 'mutation_overlap', 'stage_order': 3}
# 196621-dc260:{'input': ['columns.txt', 'sifted.SIFT.chr9.txt', 'chr9n.tar.gz'], 'output': ['chr9-AFR.tar.gz'], 'prevTask': 'initial_data', 'taskName': 'mutation_overlap', 'stage_order': 3}
# 196637-dc260:{'input': ['columns.txt', 'sifted.SIFT.chr9.txt', 'chr9n.tar.gz'], 'output': ['chr9-ALL.tar.gz'], 'prevTask': 'initial_data', 'taskName': 'mutation_overlap', 'stage_order': 3}
# 196639-dc260:{'input': ['columns.txt', 'chr9n.tar.gz', 'sifted.SIFT.chr9.txt'], 'output': ['chr9-EAS.tar.gz'], 'prevTask': 'initial_data', 'taskName': 'mutation_overlap', 'stage_order': 3}
# 196641-dc260:{'input': ['chr9n.tar.gz', 'sifted.SIFT.chr9.txt', 'columns.txt'], 'output': ['chr9-GBR.tar.gz'], 'prevTask': 'initial_data', 'taskName': 'mutation_overlap', 'stage_order': 3}
# 196643-dc260:{'input': ['chr9n.tar.gz', 'sifted.SIFT.chr9.txt', 'columns.txt'], 'output': ['chr9-GBR-freq.tar.gz'], 'prevTask': 'initial_data', 'taskName': 'frequency', 'stage_order': 3}
# 196645-dc260:{'input': ['chr9n.tar.gz', 'sifted.SIFT.chr9.txt', 'columns.txt'], 'output': ['chr9-SAS-freq.tar.gz'], 'prevTask': 'initial_data', 'taskName': 'frequency', 'stage_order': 3}
# 196647-dc260:{'input': ['sifted.SIFT.chr9.txt', 'columns.txt', 'chr9n.tar.gz'], 'output': ['chr9-EUR-freq.tar.gz'], 'prevTask': 'initial_data', 'taskName': 'frequency', 'stage_order': 3}
# 196649-dc260:{'input': ['chr9n.tar.gz', 'sifted.SIFT.chr9.txt', 'columns.txt'], 'output': ['chr9-AMR-freq.tar.gz'], 'prevTask': 'initial_data', 'taskName': 'frequency', 'stage_order': 3}
# 196651-dc260:{'input': ['chr9n.tar.gz', 'columns.txt', 'sifted.SIFT.chr9.txt'], 'output': ['chr9-EAS-freq.tar.gz'], 'prevTask': 'initial_data', 'taskName': 'frequency', 'stage_order': 3}
# 196653-dc260:{'input': ['sifted.SIFT.chr9.txt', 'chr9n.tar.gz', 'columns.txt'], 'output': ['chr9-AFR-freq.tar.gz'], 'prevTask': 'initial_data', 'taskName': 'frequency', 'stage_order': 3}
# 196657-dc260:{'input': ['chr9n.tar.gz', 'sifted.SIFT.chr9.txt', 'columns.txt'], 'output': ['chr9-ALL-freq.tar.gz'], 'prevTask': 'initial_data', 'taskName': 'frequency', 'stage_order': 3}
# 196658-dc260:{'input': ['columns.txt', 'sifted.SIFT.chr9.txt', 'chr9n.tar.gz'], 'output': ['chr9-AMR.tar.gz'], 'prevTask': 'initial_data', 'taskName': 'mutation_overlap', 'stage_order': 3}
# 1968-dc148:{'input': ['chr5n.tar.gz', 'columns.txt', 'sifted.SIFT.chr5.txt'], 'output': ['chr5-GBR.tar.gz'], 'prevTask': 'initial_data', 'taskName': 'mutation_overlap', 'stage_order': 3}
# 1970-dc148:{'input': ['columns.txt', 'sifted.SIFT.chr5.txt', 'chr5n.tar.gz'], 'output': ['chr5-SAS.tar.gz'], 'prevTask': 'initial_data', 'taskName': 'mutation_overlap', 'stage_order': 3}
# 1972-dc148:{'input': ['sifted.SIFT.chr5.txt', 'columns.txt', 'chr5n.tar.gz'], 'output': ['chr5-SAS-freq.tar.gz'], 'prevTask': 'initial_data', 'taskName': 'frequency', 'stage_order': 3}
# 1974-dc148:{'input': ['columns.txt', 'chr5n.tar.gz', 'sifted.SIFT.chr5.txt'], 'output': ['chr5-EUR-freq.tar.gz'], 'prevTask': 'initial_data', 'taskName': 'frequency', 'stage_order': 3}
# 1977-dc148:{'input': ['columns.txt', 'chr5n.tar.gz', 'sifted.SIFT.chr5.txt'], 'output': ['chr5-AFR.tar.gz'], 'prevTask': 'initial_data', 'taskName': 'mutation_overlap', 'stage_order': 3}
# 1978-dc148:{'input': ['sifted.SIFT.chr5.txt', 'columns.txt', 'chr5n.tar.gz'], 'output': ['chr5-AMR-freq.tar.gz'], 'prevTask': 'initial_data', 'taskName': 'frequency', 'stage_order': 3}
# 24989-dc135:{'input': ['ALL.chr3.250000.vcf', 'columns.txt'], 'output': ['chr3n-2401-2601.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 24992-dc135:{'input': ['columns.txt', 'ALL.chr3.250000.vcf'], 'output': ['chr3n-1001-1201.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 25009-dc135:{'input': ['ALL.chr3.250000.vcf', 'columns.txt'], 'output': ['chr3n-2001-2201.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 25020-dc135:{'input': ['columns.txt', 'ALL.chr3.250000.vcf'], 'output': ['chr3n-201-401.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 25026-dc135:{'input': ['ALL.chr3.250000.vcf', 'columns.txt'], 'output': ['chr3n-2601-2801.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 25051-dc135:{'input': ['ALL.chr3.250000.vcf', 'columns.txt'], 'output': ['chr3n-1201-1401.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 25078-dc135:{'input': ['columns.txt', 'ALL.chr3.250000.vcf'], 'output': ['chr3n-3001-3201.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 25084-dc135:{'input': ['columns.txt', 'ALL.chr3.250000.vcf'], 'output': ['chr3n-801-1001.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 25087-dc135:{'input': ['columns.txt', 'ALL.chr3.250000.vcf'], 'output': ['chr3n-1801-2001.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 25106-dc135:{'input': ['ALL.chr3.250000.vcf', 'columns.txt'], 'output': ['chr3n-3601-3801.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 25128-dc135:{'input': ['columns.txt', 'ALL.chr3.250000.vcf'], 'output': ['chr3n-4201-4401.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 25140-dc135:{'input': ['ALL.chr3.250000.vcf', 'columns.txt'], 'output': ['chr3n-3801-4001.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 25142-dc135:{'input': ['ALL.chr3.250000.vcf', 'columns.txt'], 'output': ['chr3n-4801-5001.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 25146-dc135:{'input': ['columns.txt', 'ALL.chr3.250000.vcf'], 'output': ['chr3n-2201-2401.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 25147-dc135:{'input': ['columns.txt', 'ALL.chr3.250000.vcf'], 'output': ['chr3n-401-601.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 25149-dc135:{'input': ['ALL.chr3.250000.vcf', 'columns.txt'], 'output': ['chr3n-5401-5601.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 25151-dc135:{'input': ['columns.txt', 'ALL.chr3.250000.vcf'], 'output': ['chr3n-5801-6001.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 25153-dc135:{'input': ['columns.txt', 'ALL.chr3.250000.vcf'], 'output': ['chr3n-3201-3401.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 25155-dc135:{'input': ['ALL.chr3.250000.vcf', 'columns.txt'], 'output': ['chr3n-3401-3601.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 25163-dc135:{'input': ['columns.txt', 'ALL.chr3.250000.vcf'], 'output': ['chr3n-2801-3001.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 25165-dc135:{'input': ['ALL.chr3.250000.vcf', 'columns.txt'], 'output': ['chr3n-1401-1601.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 25166-dc135:{'input': ['ALL.chr3.250000.vcf', 'columns.txt'], 'output': ['chr3n-1601-1801.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 25168-dc135:{'input': ['columns.txt', 'ALL.chr3.250000.vcf'], 'output': ['chr3n-4401-4601.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 25170-dc135:{'input': ['columns.txt', 'ALL.chr3.250000.vcf'], 'output': ['chr3n-4601-4801.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 25172-dc135:{'input': ['ALL.chr3.250000.vcf', 'columns.txt'], 'output': ['chr3n-1-201.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 25174-dc135:{'input': ['columns.txt', 'ALL.chr3.250000.vcf'], 'output': ['chr3n-4001-4201.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 25176-dc135:{'input': ['columns.txt', 'ALL.chr3.250000.vcf'], 'output': ['chr3n-601-801.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 25179-dc135:{'input': ['ALL.chr3.250000.vcf', 'columns.txt'], 'output': ['chr3n-5001-5201.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 25181-dc135:{'input': ['ALL.chr3.250000.vcf', 'columns.txt'], 'output': ['chr3n-5601-5801.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 25182-dc135:{'input': ['ALL.chr3.250000.vcf', 'columns.txt'], 'output': ['chr3n-5201-5401.tar.gz'], 'prevTask': '', 'taskName': 'individuals', 'stage_order': 1}
# 25630-dc135:{'input': ['chr3n-4801-5001.tar.gz', 'chr3n-4601-4801.tar.gz', 'chr3n-1001-1201.tar.gz', 'chr3n-801-1001.tar.gz', 'chr3n-5801-6001.tar.gz', 'chr3n-1801-2001.tar.gz', 'chr3n-2801-3001.tar.gz', 'chr3n-3601-3801.tar.gz', 'chr3n-4201-4401.tar.gz', 'chr3n-3001-3201.tar.gz', 'chr3n-1201-1401.tar.gz', 'chr3n-5201-5401.tar.gz', 'chr3n-5401-5601.tar.gz', 'chr3n-401-601.tar.gz', 'chr3n-1601-1801.tar.gz', 'chr3n-5001-5201.tar.gz', 'chr3n-1-201.tar.gz', 'chr3n-4001-4201.tar.gz', 'chr3n-3801-4001.tar.gz', 'chr3n-2401-2601.tar.gz', 'chr3n-5601-5801.tar.gz', 'chr3n-2001-2201.tar.gz', 'chr3n-2601-2801.tar.gz', 'chr3n-4401-4601.tar.gz', 'chr3n-1401-1601.tar.gz', 'chr3n-601-801.tar.gz', 'chr3n-2201-2401.tar.gz', 'chr3n-3201-3401.tar.gz', 'chr3n-201-401.tar.gz', 'chr3n-3401-3601.tar.gz'], 'output': ['chr3n.tar.gz'], 'prevTask': '', 'taskName': 'individuals_merge', 'stage_order': 2}
# 25632-dc135:{'input': ['ALL.chr3.phase3_shapeit2_mvncall_integrated_v5.20130502.sites.annotation.vcf', 'SIFT.chr3.vcf'], 'output': ['sifted.SIFT.chr3.txt'], 'prevTask': '', 'taskName': 'sifting', 'stage_order': 2}
# 25645-dc135:{'input': ['ALL.chr3.phase3_shapeit2_mvncall_integrated_v5.20130502.sites.annotation.vcf'], 'output': [], 'prevTask': 'initial_data', 'taskName': 'sifting', 'stage_order': 2}
# 26649-dc135:{'input': ['chr3n.tar.gz', 'columns.txt', 'sifted.SIFT.chr3.txt'], 'output': ['chr3-SAS.tar.gz'], 'prevTask': 'initial_data', 'taskName': 'mutation_overlap', 'stage_order': 3}
# 26657-dc135:{'input': ['sifted.SIFT.chr3.txt', 'columns.txt', 'chr3n.tar.gz'], 'output': ['chr3-EUR.tar.gz'], 'prevTask': 'initial_data', 'taskName': 'mutation_overlap', 'stage_order': 3}
# 26688-dc135:{'input': ['columns.txt', 'chr3n.tar.gz', 'sifted.SIFT.chr3.txt'], 'output': ['chr3-ALL.tar.gz'], 'prevTask': 'initial_data', 'taskName': 'mutation_overlap', 'stage_order': 3}
# 26698-dc135:{'input': ['sifted.SIFT.chr3.txt', 'columns.txt', 'chr3n.tar.gz'], 'output': ['chr3-EAS.tar.gz'], 'prevTask': 'initial_data', 'taskName': 'mutation_overlap', 'stage_order': 3}
# 26700-dc135:{'input': ['chr3n.tar.gz', 'columns.txt', 'sifted.SIFT.chr3.txt'], 'output': ['chr3-GBR.tar.gz'], 'prevTask': 'initial_data', 'taskName': 'mutation_overlap', 'stage_order': 3}
# 26702-dc135:{'input': ['columns.txt', 'sifted.SIFT.chr3.txt', 'chr3n.tar.gz'], 'output': ['chr3-AFR.tar.gz'], 'prevTask': 'initial_data', 'taskName': 'mutation_overlap', 'stage_order': 3}
# 26704-dc135:{'input': ['chr3n.tar.gz', 'columns.txt', 'sifted.SIFT.chr3.txt'], 'output': ['chr3-EAS-freq.tar.gz'], 'prevTask': 'initial_data', 'taskName': 'frequency', 'stage_order': 3}
# 26706-dc135:{'input': ['chr3n.tar.gz', 'columns.txt', 'sifted.SIFT.chr3.txt'], 'output': ['chr3-ALL-freq.tar.gz'], 'prevTask': 'initial_data', 'taskName': 'frequency', 'stage_order': 3}
# 26708-dc135:{'input': ['columns.txt', 'chr3n.tar.gz', 'sifted.SIFT.chr3.txt'], 'output': ['chr3-GBR-freq.tar.gz'], 'prevTask': 'initial_data', 'taskName': 'frequency', 'stage_order': 3}
# 26710-dc135:{'input': ['chr3n.tar.gz', 'columns.txt', 'sifted.SIFT.chr3.txt'], 'output': ['chr3-AFR-freq.tar.gz'], 'prevTask': 'initial_data', 'taskName': 'frequency', 'stage_order': 3}
# 26712-dc135:{'input': ['columns.txt', 'chr3n.tar.gz', 'sifted.SIFT.chr3.txt'], 'output': ['chr3-EUR-freq.tar.gz'], 'prevTask': 'initial_data', 'taskName': 'frequency', 'stage_order': 3}
# 26714-dc135:{'input': ['columns.txt', 'chr3n.tar.gz', 'sifted.SIFT.chr3.txt'], 'output': ['chr3-SAS-freq.tar.gz'], 'prevTask': 'initial_data', 'taskName': 'frequency', 'stage_order': 3}
# 26716-dc135:{'input': ['chr3n.tar.gz', 'sifted.SIFT.chr3.txt', 'columns.txt'], 'output': ['chr3-AMR-freq.tar.gz'], 'prevTask': 'initial_data', 'taskName': 'frequency', 'stage_order': 3}
# ...
# 823-dc148:{'input': ['ALL.chr5.phase3_shapeit2_mvncall_integrated_v5.20130502.sites.annotation.vcf', 'SIFT.chr5.vcf'], 'output': ['sifted.SIFT.chr5.txt'], 'prevTask': '', 'taskName': 'sifting', 'stage_order': 2}
# 824-dc148:{'input': ['chr5n-601-801.tar.gz', 'chr5n-5801-6001.tar.gz', 'chr5n-4601-4801.tar.gz', 'chr5n-5601-5801.tar.gz', 'chr5n-801-1001.tar.gz', 'chr5n-5201-5401.tar.gz', 'chr5n-2801-3001.tar.gz', 'chr5n-1001-1201.tar.gz', 'chr5n-2001-2201.tar.gz', 'chr5n-401-601.tar.gz', 'chr5n-1201-1401.tar.gz', 'chr5n-1601-1801.tar.gz', 'chr5n-3401-3601.tar.gz', 'chr5n-201-401.tar.gz', 'chr5n-2401-2601.tar.gz', 'chr5n-3201-3401.tar.gz', 'chr5n-4801-5001.tar.gz', 'chr5n-1401-1601.tar.gz', 'chr5n-3801-4001.tar.gz', 'chr5n-4001-4201.tar.gz', 'chr5n-4401-4601.tar.gz', 'chr5n-4201-4401.tar.gz', 'chr5n-2601-2801.tar.gz', 'chr5n-3001-3201.tar.gz', 'chr5n-5401-5601.tar.gz', 'chr5n-3601-3801.tar.gz', 'chr5n-1801-2001.tar.gz', 'chr5n-5001-5201.tar.gz', 'chr5n-2201-2401.tar.gz', 'chr5n-1-201.tar.gz'], 'output': ['chr5n.tar.gz'], 'prevTask': '', 'taskName': 'individuals_merge', 'stage_order': 2}
# 8312-dc111:{'input': ['columns.txt', 'chr2n.tar.gz', 'sifted.SIFT.chr2.txt'], 'output': ['chr2-AMR.tar.gz'], 'prevTask': 'initial_data', 'taskName': 'mutation_overlap', 'stage_order': 3}
# 8313-dc111:{'input': ['columns.txt', 'sifted.SIFT.chr2.txt', 'chr2n.tar.gz'], 'output': ['chr2-GBR.tar.gz'], 'prevTask': 'initial_data', 'taskName': 'mutation_overlap', 'stage_order': 3}
# 8323-dc111:{'input': ['sifted.SIFT.chr2.txt', 'chr2n.tar.gz', 'columns.txt'], 'output': ['chr2-AFR.tar.gz'], 'prevTask': 'initial_data', 'taskName': 'mutation_overlap', 'stage_order': 3}
# 8325-dc111:{'input': ['sifted.SIFT.chr2.txt', 'columns.txt', 'chr2n.tar.gz'], 'output': ['chr2-ALL.tar.gz'], 'prevTask': 'initial_data', 'taskName': 'mutation_overlap', 'stage_order': 3}
# 8338-dc111:{'input': ['sifted.SIFT.chr2.txt', 'chr2n.tar.gz', 'columns.txt'], 'output': ['chr2-SAS-freq.tar.gz'], 'prevTask': 'initial_data', 'taskName': 'frequency', 'stage_order': 3}
# 8339-dc111:{'input': ['sifted.SIFT.chr2.txt', 'columns.txt', 'chr2n.tar.gz'], 'output': ['chr2-EAS.tar.gz'], 'prevTask': 'initial_data', 'taskName': 'mutation_overlap', 'stage_order': 3}
# 8352-dc111:{'input': ['columns.txt', 'sifted.SIFT.chr2.txt', 'chr2n.tar.gz'], 'output': ['chr2-EAS-freq.tar.gz'], 'prevTask': 'initial_data', 'taskName': 'frequency', 'stage_order': 3}
# 8361-dc111:{'input': ['columns.txt', 'sifted.SIFT.chr2.txt', 'chr2n.tar.gz'], 'output': ['chr2-SAS.tar.gz'], 'prevTask': 'initial_data', 'taskName': 'mutation_overlap', 'stage_order': 3}
# 8371-dc111:{'input': ['sifted.SIFT.chr2.txt', 'chr2n.tar.gz', 'columns.txt'], 'output': ['chr2-ALL-freq.tar.gz'], 'prevTask': 'initial_data', 'taskName': 'frequency', 'stage_order': 3}
# 8373-dc111:{'input': ['columns.txt', 'chr2n.tar.gz', 'sifted.SIFT.chr2.txt'], 'output': ['chr2-EUR-freq.tar.gz'], 'prevTask': 'initial_data', 'taskName': 'frequency', 'stage_order': 3}
# 8375-dc111:{'input': ['chr2n.tar.gz', 'sifted.SIFT.chr2.txt', 'columns.txt'], 'output': ['chr2-EUR.tar.gz'], 'prevTask': 'initial_data', 'taskName': 'mutation_overlap', 'stage_order': 3}
# 8378-dc111:{'input': ['columns.txt', 'chr2n.tar.gz', 'sifted.SIFT.chr2.txt'], 'output': ['chr2-AMR-freq.tar.gz'], 'prevTask': 'initial_data', 'taskName': 'frequency', 'stage_order': 3}
# 8380-dc111:{'input': ['sifted.SIFT.chr2.txt', 'chr2n.tar.gz', 'columns.txt'], 'output': ['chr2-GBR-freq.tar.gz'], 'prevTask': 'initial_data', 'taskName': 'frequency', 'stage_order': 3}
# 8382-dc111:{'input': ['sifted.SIFT.chr2.txt', 'columns.txt', 'chr2n.tar.gz'], 'output': ['chr2-AFR-freq.tar.gz'], 'prevTask': 'initial_data', 'taskName': 'frequency', 'stage_order': 3}
# 845-dc148:{'input': ['ALL.chr5.phase3_shapeit2_mvncall_integrated_v5.20130502.sites.annotation.vcf'], 'output': [], 'prevTask': 'initial_data', 'taskName': 'sifting', 'stage_order': 2}
# all_wf_dict-----
# ['chr2n-2201-2401.tar.gz' 'ALL.chr2.250000.vcf' 'columns.txt'
#  'ALL.chr3.250000.vcf' 'chr3n-1201-1401.tar.gz' 'ALL.chr8.250000.vcf'
#  'chr8n-1401-1601.tar.gz' 'chr3n-4601-4801.tar.gz' 'ALL.chr10.250000.vcf'
#  'chr10n-5601-5801.tar.gz' 'chr4n.tar.gz' 'sifted.SIFT.chr4.txt'
#  'chr4-AFR-freq.tar.gz' 'chr8n-1-201.tar.gz' 'chr10n-4401-4601.tar.gz'
#  'chr2-EAS-freq.tar.gz' 'sifted.SIFT.chr2.txt' 'chr2n.tar.gz'
#  'chr4-SAS-freq.tar.gz' 'chr9n-2201-2401.tar.gz' 'ALL.chr9.250000.vcf'
#  'sifted.SIFT.chr6.txt' 'chr6n.tar.gz' 'chr6-AFR-freq.tar.gz'
#  'chr7n.tar.gz' 'sifted.SIFT.chr7.txt' 'chr7-ALL.tar.gz'
#  'chr9n-5001-5201.tar.gz' 'sifted.SIFT.chr9.txt' 'chr9-EUR-freq.tar.gz'
#  'chr9n.tar.gz' 'chr2n-4001-4201.tar.gz' 'chr7n-5201-5401.tar.gz'
#  'ALL.chr7.250000.vcf' 'chr1n.tar.gz' 'sifted.SIFT.chr1.txt'
#  'chr1-SAS-freq.tar.gz' 'chr9-GBR-freq.tar.gz' 'ALL.chr5.250000.vcf'
#  'chr5n-1001-1201.tar.gz' 'chr5n-4201-4401.tar.gz' 'chr10n.tar.gz'
#  'sifted.SIFT.chr10.txt' 'chr10-AMR.tar.gz' 'chr3n-5401-5601.tar.gz'
#  'chr10n-3401-3601.tar.gz' 'chr7n-1401-1601.tar.gz'
#  'ALL.chr10.phase3_shapeit2_mvncall_integrated_v5.20130502.sites.annotation.vcf'
#  'SIFT.chr10.vcf' 'chr3n.tar.gz' 'sifted.SIFT.chr3.txt' 'chr3-GBR.tar.gz'
#  'chr8n.tar.gz' 'sifted.SIFT.chr8.txt' 'chr8-AFR-freq.tar.gz'
#  'chr6n-1401-1601.tar.gz' 'ALL.chr6.250000.vcf' 'chr5n-2001-2201.tar.gz'
#  'chr6-ALL-freq.tar.gz' 'chr6n-2001-2201.tar.gz' 'chr10n-5801-6001.tar.gz'
#  'chr8-GBR-freq.tar.gz' 'chr7n-2401-2601.tar.gz' 'ALL.chr4.250000.vcf'
#  'chr4n-5401-5601.tar.gz' 'chr1-ALL-freq.tar.gz'
#  'ALL.chr4.phase3_shapeit2_mvncall_integrated_v5.20130502.sites.annotation.vcf'
#  'SIFT.chr4.vcf' 'chr3n-4001-4201.tar.gz'
#  'ALL.chr7.phase3_shapeit2_mvncall_integrated_v5.20130502.sites.annotation.vcf'
#  'SIFT.chr7.vcf' 'chr2n-4601-4801.tar.gz' 'chr9n-5601-5801.tar.gz'
#  'chr6n-2601-2801.tar.gz' 'chr8-ALL-freq.tar.gz' 'chr9-AFR.tar.gz'
#  'chr10n-1001-1201.tar.gz' 'chr6n-5801-6001.tar.gz'
#  'chr8n-5001-5201.tar.gz' 'chr8n-2001-2201.tar.gz'
#  'chr4n-4801-5001.tar.gz' 'chr3n-601-801.tar.gz' 'chr5n-4001-4201.tar.gz'
#  'chr8n-3801-4001.tar.gz' 'chr10-SAS-freq.tar.gz' 'chr6-AMR-freq.tar.gz'
#  'chr8n-201-401.tar.gz' 'chr4n-4201-4401.tar.gz' 'chr10-AFR.tar.gz'
#  'chr9-GBR.tar.gz' 'chr9n-2001-2201.tar.gz' 'chr9n-3801-4001.tar.gz'
#  'chr3-SAS-freq.tar.gz' 'chr2n-4201-4401.tar.gz' 'chr6-EAS.tar.gz'
#  'chr9n-1401-1601.tar.gz' 'chr7-AFR-freq.tar.gz'
#  'ALL.chr5.phase3_shapeit2_mvncall_integrated_v5.20130502.sites.annotation.vcf'
#  'chr6-EUR.tar.gz' 'chr2-AMR-freq.tar.gz' 'chr8n-3201-3401.tar.gz'
#  'chr9n-601-801.tar.gz' 'chr10n-3201-3401.tar.gz'
#  'chr10n-4601-4801.tar.gz' 'chr2-AFR-freq.tar.gz' 'ALL.chr1.250000.vcf'
#  'chr1n-5201-5401.tar.gz' 'chr10n-3001-3201.tar.gz'
#  'chr10n-1801-2001.tar.gz' 'chr10n-4201-4401.tar.gz'
#  'chr10n-201-401.tar.gz' 'chr10n-4001-4201.tar.gz'
#  'chr10n-1201-1401.tar.gz' 'chr10n-2201-2401.tar.gz' 'chr10n-1-201.tar.gz'
#  'chr10n-3801-4001.tar.gz' 'chr10n-5401-5601.tar.gz'
#  'chr10n-5001-5201.tar.gz' 'chr10n-1401-1601.tar.gz'
#  'chr10n-1601-1801.tar.gz' 'chr10n-3601-3801.tar.gz'
#  'chr10n-401-601.tar.gz' 'chr10n-5201-5401.tar.gz' 'chr10n-601-801.tar.gz'
#  'chr10n-2401-2601.tar.gz' 'chr10n-801-1001.tar.gz'
#  'chr10n-4801-5001.tar.gz' 'chr10n-2001-2201.tar.gz'
#  'chr10n-2801-3001.tar.gz' 'chr10n-2601-2801.tar.gz'
#  'chr5n-3201-3401.tar.gz' 'chr4n-201-401.tar.gz' 'chr6n-5001-5201.tar.gz'
#  'chr5n-1601-1801.tar.gz' 'chr6n-5601-5801.tar.gz' 'chr8-AMR.tar.gz'
#  'chr4n-2801-3001.tar.gz' 'chr7n-3201-3401.tar.gz' 'chr2n-601-801.tar.gz'
#  'chr1-AMR.tar.gz' 'chr1n-2601-2801.tar.gz' 'chr3n-4801-5001.tar.gz'
#  'chr5n-201-401.tar.gz' 'chr2n-401-601.tar.gz' 'chr6-SAS-freq.tar.gz'
#  'chr2-SAS.tar.gz' 'chr7-AMR-freq.tar.gz' 'chr3n-3601-3801.tar.gz'
#  'chr8n-3001-3201.tar.gz' 'chr7n-1801-2001.tar.gz' 'chr8-EAS-freq.tar.gz'
#  'chr4n-3201-3401.tar.gz' 'chr7n-3001-3201.tar.gz'
#  'chr1n-3601-3801.tar.gz' 'chr6n-2401-2601.tar.gz'
#  'chr3n-1001-1201.tar.gz' 'chr7n-4601-4801.tar.gz'
#  'ALL.chr8.phase3_shapeit2_mvncall_integrated_v5.20130502.sites.annotation.vcf'
#  'SIFT.chr8.vcf' 'chr8-SAS.tar.gz'
#  'ALL.chr2.phase3_shapeit2_mvncall_integrated_v5.20130502.sites.annotation.vcf'
#  'chr2-ALL.tar.gz' 'chr2n-4801-5001.tar.gz' 'chr7n-5401-5601.tar.gz'
#  'chr7n-3401-3601.tar.gz' 'chr7n-2601-2801.tar.gz' 'chr7n-601-801.tar.gz'
#  'chr7n-3601-3801.tar.gz' 'chr7n-201-401.tar.gz' 'chr7n-5801-6001.tar.gz'
#  'chr7n-1601-1801.tar.gz' 'chr7n-1-201.tar.gz' 'chr7n-401-601.tar.gz'
#  'chr7n-801-1001.tar.gz' 'chr7n-1201-1401.tar.gz' 'chr7n-5001-5201.tar.gz'
#  'chr7n-2801-3001.tar.gz' 'chr7n-5601-5801.tar.gz'
#  'chr7n-3801-4001.tar.gz' 'chr7n-4801-5001.tar.gz'
#  'chr7n-4201-4401.tar.gz' 'chr7n-1001-1201.tar.gz'
#  'chr7n-4001-4201.tar.gz' 'chr7n-2201-2401.tar.gz'
#  'chr7n-2001-2201.tar.gz' 'chr7n-4401-4601.tar.gz' 'chr6-ALL.tar.gz'
#  'chr5n-401-601.tar.gz' 'chr1-GBR-freq.tar.gz' 'chr9n-4001-4201.tar.gz'
#  'chr10-ALL-freq.tar.gz' 'chr4n-4401-4601.tar.gz' 'chr4n-1401-1601.tar.gz'
#  'chr8-EAS.tar.gz' 'chr6n-2201-2401.tar.gz' 'chr9n-1601-1801.tar.gz'
#  'chr2n-3801-4001.tar.gz' 'chr9-ALL-freq.tar.gz' 'chr7-EUR.tar.gz'
#  'chr8n-5201-5401.tar.gz' 'chr5n-1401-1601.tar.gz'
#  'chr5n-2201-2401.tar.gz' 'chr3n-3401-3601.tar.gz'
#  'chr6n-4001-4201.tar.gz' 'chr10-EUR-freq.tar.gz' 'chr9n-2601-2801.tar.gz'
#  'chr3n-3801-4001.tar.gz' 'chr2n-3001-3201.tar.gz' 'chr8-EUR.tar.gz'
#  'chr3-GBR-freq.tar.gz' 'chr4n-4001-4201.tar.gz' 'chr4n-2001-2201.tar.gz'
#  'chr4n-3401-3601.tar.gz' 'chr4n-2601-2801.tar.gz'
#  'chr4n-3601-3801.tar.gz' 'chr4n-5001-5201.tar.gz' 'chr4n-801-1001.tar.gz'
#  'chr4n-1-201.tar.gz' 'chr4n-4601-4801.tar.gz' 'chr4n-1201-1401.tar.gz'
#  'chr4n-1601-1801.tar.gz' 'chr4n-3801-4001.tar.gz'
#  'chr4n-5801-6001.tar.gz' 'chr4n-3001-3201.tar.gz'
#  'chr4n-1001-1201.tar.gz' 'chr4n-2201-2401.tar.gz'
#  'chr4n-1801-2001.tar.gz' 'chr4n-401-601.tar.gz' 'chr4n-5601-5801.tar.gz'
#  'chr4n-2401-2601.tar.gz' 'chr4n-601-801.tar.gz' 'chr4n-5201-5401.tar.gz'
#  'chr8-ALL.tar.gz' 'chr7-EUR-freq.tar.gz' 'chr2n-1401-1601.tar.gz'
#  'chr1-AMR-freq.tar.gz' 'chr6-GBR.tar.gz' 'chr6n-3401-3601.tar.gz'
#  'chr2-ALL-freq.tar.gz' 'chr1n-5801-6001.tar.gz' 'chr4-GBR.tar.gz'
#  'chr8n-3601-3801.tar.gz' 'chr3n-801-1001.tar.gz' 'chr9n-3201-3401.tar.gz'
#  'chr3n-1401-1601.tar.gz' 'chr1n-1001-1201.tar.gz'
#  'chr3n-3201-3401.tar.gz' 'chr7-GBR-freq.tar.gz' 'chr6-SAS.tar.gz'
#  'chr8n-4601-4801.tar.gz' 'chr1n-401-601.tar.gz' 'chr6-EUR-freq.tar.gz'
#  'chr2n-1001-1201.tar.gz' 'chr1-AFR-freq.tar.gz' 'chr3n-201-401.tar.gz'
#  'chr10-EAS.tar.gz' 'chr9n-801-1001.tar.gz' 'chr1n-2001-2201.tar.gz'
#  'chr3n-2801-3001.tar.gz' 'chr8n-5801-6001.tar.gz'
#  'chr2n-5601-5801.tar.gz' 'chr9n-5801-6001.tar.gz' 'chr4-EAS.tar.gz'
#  'chr8n-601-801.tar.gz' 'chr6-AFR.tar.gz' 'chr5n-3601-3801.tar.gz'
#  'chr3-ALL.tar.gz' 'chr8n-3401-3601.tar.gz' 'chr4-EUR.tar.gz'
#  'chr8n-4801-5001.tar.gz' 'chr9n-2401-2601.tar.gz'
#  'chr2n-1601-1801.tar.gz' 'chr1n-201-401.tar.gz' 'chr8n-1801-2001.tar.gz'
#  'chr1n-1-201.tar.gz' 'chr1n-5001-5201.tar.gz' 'chr1n-601-801.tar.gz'
#  'chr8n-4401-4601.tar.gz' 'chr8n-801-1001.tar.gz' 'chr8n-1601-1801.tar.gz'
#  'chr2n-2601-2801.tar.gz' 'chr8n-2601-2801.tar.gz'
#  'chr6n-1801-2001.tar.gz' 'chr3-EUR-freq.tar.gz' 'chr3n-1801-2001.tar.gz'
#  'chr5n.tar.gz' 'chr5-EUR.tar.gz' 'sifted.SIFT.chr5.txt'
#  'chr5n-5201-5401.tar.gz' 'chr5n-601-801.tar.gz' 'chr3-AMR-freq.tar.gz'
#  'chr1-EUR.tar.gz' 'chr9n-3001-3201.tar.gz' 'chr3-EUR.tar.gz'
#  'chr2n-201-401.tar.gz'
#  'ALL.chr9.phase3_shapeit2_mvncall_integrated_v5.20130502.sites.annotation.vcf'
#  'SIFT.chr9.vcf' 'chr2-GBR-freq.tar.gz' 'chr3n-401-601.tar.gz'
#  'chr8n-2801-3001.tar.gz' 'chr8n-4201-4401.tar.gz'
#  'chr8n-5401-5601.tar.gz' 'chr8n-401-601.tar.gz' 'chr8n-2201-2401.tar.gz'
#  'chr8n-1001-1201.tar.gz' 'chr8n-4001-4201.tar.gz'
#  'chr8n-5601-5801.tar.gz' 'chr8n-1201-1401.tar.gz'
#  'chr8n-2401-2601.tar.gz' 'chr1n-4801-5001.tar.gz' 'chr2-AMR.tar.gz'
#  'chr9n-5401-5601.tar.gz' 'chr2n-2801-3001.tar.gz' 'chr1-GBR.tar.gz'
#  'chr5n-4601-4801.tar.gz' 'chr3n-4201-4401.tar.gz'
#  'chr1n-2801-3001.tar.gz' 'chr1n-3201-3401.tar.gz'
#  'chr1n-3401-3601.tar.gz' 'chr1n-4401-4601.tar.gz'
#  'chr1n-1801-2001.tar.gz' 'chr1n-2201-2401.tar.gz'
#  'chr1n-4201-4401.tar.gz' 'chr1n-4001-4201.tar.gz'
#  'chr1n-4601-4801.tar.gz' 'chr1n-801-1001.tar.gz' 'chr1n-5601-5801.tar.gz'
#  'chr1n-3801-4001.tar.gz' 'chr1n-1401-1601.tar.gz'
#  'chr1n-2401-2601.tar.gz' 'chr1n-1201-1401.tar.gz'
#  'chr1n-5401-5601.tar.gz' 'chr1n-1601-1801.tar.gz'
#  'chr1n-3001-3201.tar.gz' 'chr5-GBR-freq.tar.gz' 'chr6n-3601-3801.tar.gz'
#  'chr5n-5401-5601.tar.gz' 'chr5n-3801-4001.tar.gz' 'SIFT.chr2.vcf'
#  'chr4-EAS-freq.tar.gz' 'chr3n-4401-4601.tar.gz' 'chr9n-4601-4801.tar.gz'
#  'chr6n-201-401.tar.gz' 'chr10-EAS-freq.tar.gz' 'chr9-AMR.tar.gz'
#  'chr7-ALL-freq.tar.gz' 'chr1-EAS.tar.gz' 'chr9n-201-401.tar.gz'
#  'chr10-AFR-freq.tar.gz' 'chr2n-4401-4601.tar.gz' 'chr5n-5801-6001.tar.gz'
#  'chr3n-1601-1801.tar.gz' 'chr3-EAS.tar.gz' 'chr6n-401-601.tar.gz'
#  'chr5-EUR-freq.tar.gz' 'chr2n-3601-3801.tar.gz' 'chr10-GBR.tar.gz'
#  'chr4-EUR-freq.tar.gz' 'chr9-AMR-freq.tar.gz' 'chr4-AMR.tar.gz'
#  'chr5-AFR-freq.tar.gz' 'chr4-SAS.tar.gz' 'chr4-GBR-freq.tar.gz'
#  'chr4-ALL-freq.tar.gz' 'chr7-AFR.tar.gz' 'chr6n-5201-5401.tar.gz'
#  'chr6n-1601-1801.tar.gz' 'chr9-ALL.tar.gz' 'chr3-AFR-freq.tar.gz'
#  'chr5n-5001-5201.tar.gz' 'chr9-EUR.tar.gz' 'chr6n-5401-5601.tar.gz'
#  'chr6n-4801-5001.tar.gz' 'chr7-GBR.tar.gz' 'chr6n-4601-4801.tar.gz'
#  'chr3n-2201-2401.tar.gz' 'chr2-EUR-freq.tar.gz' 'chr2n-2401-2601.tar.gz'
#  'chr9n-3401-3601.tar.gz' 'chr2n-5001-5201.tar.gz' 'chr1-ALL.tar.gz'
#  'ALL.chr3.phase3_shapeit2_mvncall_integrated_v5.20130502.sites.annotation.vcf'
#  'chr9-EAS-freq.tar.gz' 'chr6n-3201-3401.tar.gz' 'chr10-GBR-freq.tar.gz'
#  'chr3-AMR.tar.gz' 'chr9-EAS.tar.gz' 'chr2n-1801-2001.tar.gz'
#  'chr9n-4201-4401.tar.gz' 'chr6n-3001-3201.tar.gz' 'chr6n-601-801.tar.gz'
#  'chr6n-2801-3001.tar.gz' 'chr6n-1-201.tar.gz' 'chr6n-801-1001.tar.gz'
#  'chr6n-3801-4001.tar.gz' 'chr6n-1001-1201.tar.gz'
#  'chr6n-4201-4401.tar.gz' 'chr6n-4401-4601.tar.gz'
#  'chr6n-1201-1401.tar.gz' 'chr6-GBR-freq.tar.gz' 'chr7-EAS-freq.tar.gz'
#  'chr2n-1-201.tar.gz' 'chr5-AFR.tar.gz' 'chr7-SAS-freq.tar.gz'
#  'chr5-ALL.tar.gz' 'chr5n-5601-5801.tar.gz' 'chr3n-5601-5801.tar.gz'
#  'chr3-AFR.tar.gz' 'chr7-EAS.tar.gz' 'chr1-EUR-freq.tar.gz'
#  'chr4-AMR-freq.tar.gz' 'chr2n-801-1001.tar.gz' 'chr3-EAS-freq.tar.gz'
#  'chr5n-1801-2001.tar.gz' 'chr3n-5201-5401.tar.gz'
#  'chr3n-3001-3201.tar.gz' 'chr2n-5801-6001.tar.gz' 'chr9-SAS-freq.tar.gz'
#  'chr9-AFR-freq.tar.gz' 'chr9n-4401-4601.tar.gz'
#  'ALL.chr1.phase3_shapeit2_mvncall_integrated_v5.20130502.sites.annotation.vcf'
#  'SIFT.chr1.vcf' 'chr5-EAS.tar.gz' 'chr9n-1801-2001.tar.gz'
#  'chr9n-4801-5001.tar.gz' 'chr9n-401-601.tar.gz' 'chr9n-2801-3001.tar.gz'
#  'chr9n-1001-1201.tar.gz' 'chr9n-3601-3801.tar.gz'
#  'chr9n-1201-1401.tar.gz' 'chr9n-5201-5401.tar.gz' 'chr9n-1-201.tar.gz'
#  'chr2n-3201-3401.tar.gz' 'chr5n-4801-5001.tar.gz' 'chr8-AMR-freq.tar.gz'
#  'chr3n-1-201.tar.gz' 'chr10-AMR-freq.tar.gz' 'chr2n-5201-5401.tar.gz'
#  'chr2-GBR.tar.gz' 'chr8-AFR.tar.gz' 'chr5-EAS-freq.tar.gz'
#  'SIFT.chr6.vcf'
#  'ALL.chr6.phase3_shapeit2_mvncall_integrated_v5.20130502.sites.annotation.vcf'
#  'chr3-ALL-freq.tar.gz' 'chr1-AFR.tar.gz' 'chr2-AFR.tar.gz'
#  'chr5n-801-1001.tar.gz' 'chr5n-2801-3001.tar.gz' 'chr5n-1201-1401.tar.gz'
#  'chr5n-3401-3601.tar.gz' 'chr5n-2401-2601.tar.gz'
#  'chr5n-4401-4601.tar.gz' 'chr5n-2601-2801.tar.gz'
#  'chr5n-3001-3201.tar.gz' 'chr5n-1-201.tar.gz' 'chr4-ALL.tar.gz'
#  'chr5-AMR-freq.tar.gz' 'chr10-ALL.tar.gz' 'chr3n-2001-2201.tar.gz'
#  'chr3n-5001-5201.tar.gz' 'chr4-AFR.tar.gz' 'chr3n-2401-2601.tar.gz'
#  'chr3n-5801-6001.tar.gz' 'chr1-SAS.tar.gz' 'chr6-AMR.tar.gz'
#  'chr8-SAS-freq.tar.gz' 'chr2n-2001-2201.tar.gz' 'chr7-SAS.tar.gz'
#  'chr9-SAS.tar.gz' 'chr3-SAS.tar.gz' 'chr2n-5401-5601.tar.gz'
#  'chr5-GBR.tar.gz' 'chr2-SAS-freq.tar.gz' 'chr2-EUR.tar.gz'
#  'chr6-EAS-freq.tar.gz' 'chr2-EAS.tar.gz' 'chr5-ALL-freq.tar.gz'
#  'SIFT.chr3.vcf' 'chr3n-2601-2801.tar.gz' 'chr8-GBR.tar.gz'
#  'chr10-SAS.tar.gz' 'SIFT.chr5.vcf' 'chr2n-1201-1401.tar.gz'
#  'chr5-AMR.tar.gz' 'chr5-SAS-freq.tar.gz' 'chr10-EUR.tar.gz'
#  'chr2n-3401-3601.tar.gz' 'chr5-SAS.tar.gz' 'chr7-AMR.tar.gz'
#  'chr1-EAS-freq.tar.gz' 'chr8-EUR-freq.tar.gz']
# ['unknown']

# %%
# Create a mapping from taskPID to taskName
task_pid_to_name = {pid: info['taskName'] for pid, info in all_wf_dict.items()}
# print(task_pid_to_name)
# Update the DataFrame with the taskName
wf_pfs_df['taskName'] = wf_pfs_df['taskPID'].map(task_pid_to_name).fillna('unknown')

# Create a mapping from taskPID to prevTask
task_pid_to_prod_task = {pid: info['prevTask'] for pid, info in all_wf_dict.items()}
# print(task_pid_to_prod_task)
# add prevTask column to the DataFrame
wf_pfs_df['prevTask'] = wf_pfs_df['taskPID'].map(task_pid_to_prod_task).fillna('unknown')

# Print the updated DataFrame
# print(wf_pfs_df.head(5))
print(wf_pfs_df.shape)
df_unknown = wf_pfs_df[wf_pfs_df['taskName'] == 'unknown']
print(f"df unknown ({df_unknown.shape}):\n{df_unknown.head(5)}")
# print(f"df found:\n{wf_pfs_df[wf_pfs_df['taskName'] != 'unknown']}")

for pid, info in all_wf_dict.items():
    if 'stage_order' not in info:
        print(f"Missing 'stage_order' for taskPID: {pid}, info: {info}")
        if CURR_WF == "seismology":
            info['stage_order'] = 1
            info['taskName'] = "sG1IterDecon"

# Create a mapping from taskPID to stage_order
task_pid_to_stage_order = {pid: info['stage_order'] for pid, info in all_wf_dict.items()}
# print(task_pid_to_stage_order)
# add prevTask column to the DataFrame
wf_pfs_df['stageOrder'] = wf_pfs_df['taskPID'].map(task_pid_to_stage_order).fillna('-1')


# remove rows with filename contaiing string "SIFT.chr*.vcf"
for chrom in range(0, 11):
    wf_pfs_df = wf_pfs_df[~wf_pfs_df['fileName'].str.contains(f"SIFT.chr{chrom}.vcf")]
    
# Adjust dataframe prevTask
for index, row in wf_pfs_df.iterrows():
    if row['operation'] == 0:
        if row['taskName'] == '':
            wf_pfs_df.at[index, 'taskName'] = 'none'
    else:
        # Adjust read task predecessors
        taskName = row['taskName']
        fileName = row['fileName']
        if CURR_WF == "seismology":
            if taskName == '':
                # # Update taskName for read tasks to "sG1IterDecon"
                # wf_pfs_df.at[index, 'taskName'] = 'sG1IterDecon'
                taskName = 'sG1IterDecon'
                wf_pfs_df.at[index, 'taskName'] = 'sG1IterDecon'
        task_definition = task_order_dict[taskName]

        for task, inputs in task_definition['predecessors'].items():
            input_patterns = inputs['inputs']
            if matches_pattern(fileName, input_patterns):
                wf_pfs_df.at[index, 'prevTask'] = task

# Set dataframe all write operation's prevTask to empty
wf_pfs_df.loc[wf_pfs_df["operation"] == 0, "prevTask"] = ''
# Out:
# (1810, 18)
# df unknown ((0, 18)):
# Empty DataFrame
# Columns: [operation, randomOffset, transferSize, aggregateFilesizeMB, numTasks, parallelism, totalTime, numNodesList, numNodes, tasksPerNode, trMiB, storageType, opCount, taskName, taskPID, fileName, stageOrder, prevTask]
# Index: []

# %%
# print(f"df found:\n{wf_pfs_df[wf_pfs_df['taskName'] == 'trackstats']}")


# # Below values can only be updated once task name and per task parallelism is known
import math

# Assuming 'wf_pfs_df' is the DataFrame with a 'taskName' column
for index, row in wf_pfs_df.iterrows():
    task_name = row['taskName']
    if task_name in task_name_to_parallelism:
        task_parallelism = task_name_to_parallelism[task_name]
        task_num_tasks = task_name_to_num_tasks[task_name]

        
        # row['numNodesList'] = NUM_NODES
        # row['numTasks'] = task_num_tasks
        # row['tasksPerNode'] = math.ceil(task_parallelism / NUM_NODES)

        # Update the DataFrame
        wf_pfs_df.at[index, 'numNodesList'] = [NUM_NODES] #row['numNodesList']
        wf_pfs_df.at[index, 'numNodes'] = NUM_NODES #row['numNodesList']
        wf_pfs_df.at[index, 'numTasks'] = task_num_tasks
        wf_pfs_df.at[index, 'tasksPerNode'] = math.ceil(task_parallelism / NUM_NODES)
        wf_pfs_df.at[index, 'parallelism'] = task_parallelism


if DEBUG:
    print(wf_pfs_df.shape)
    print(wf_pfs_df.head(10))

# # Remove row with nan data on any of the columns
# wf_pfs_df = wf_pfs_df.dropna()
print(wf_pfs_df.shape)
# Out:
# (1800, 18)
#   operation randomOffset   transferSize  aggregateFilesizeMB numTasks  \
# 0         0            0   81791.000000             0.078002      300
# 1         1            1    8191.921474          2421.758036      300
# 2         1            1    8191.921474          2421.758036      300
# 3         1            1    8191.912230          2421.794365      300
# 4         0            0  101056.000000             0.096375      300
# 5         1            1    8191.912230          2421.794365      300
# 6         1            1    8191.922788          2421.789674      300
# 7         1            1    8191.922788          2421.789674      300
# 8         0            0   87880.000000             0.083809      300
# 9         1            1    8191.912230          2421.794365      300
#
#   parallelism  totalTime numNodesList numNodes tasksPerNode        trMiB  \
# 0         300   0.000049         [10]       10           30  1593.503085
# 1         300  19.632952         [10]       10           30   123.351699
# 2         300  19.632952         [10]       10           30   123.351699
# 3         300  19.658824         [10]       10           30   123.191215
# 4         300   0.000050         [10]       10           30  1917.557288
# 5         300  19.658824         [10]       10           30   123.191215
# 6         300  19.969613         [10]       10           30   121.273741
# 7         300  19.969613         [10]       10           30   121.273741
# 8         300   0.000039         [10]       10           30  2155.079815
# 9         300  19.657801         [10]       10           30   123.197624
#
#   storageType opCount     taskName      taskPID                fileName  \
# 0           1       1  individuals   6818-dc111  chr2n-2201-2401.tar.gz
# 1           1  309988  individuals   6818-dc111     ALL.chr2.250000.vcf
# 2           1  309988  individuals   6818-dc111             columns.txt
# 3           1  309993  individuals  25051-dc135     ALL.chr3.250000.vcf
# 4           1       1  individuals  25051-dc135  chr3n-1201-1401.tar.gz
# 5           1  309993  individuals  25051-dc135             columns.txt
# 6           1  309992  individuals  28580-dc257     ALL.chr8.250000.vcf
# 7           1  309992  individuals  28580-dc257             columns.txt
# 8           1       1  individuals  28580-dc257  chr8n-1401-1601.tar.gz
# 9           1  309993  individuals  25170-dc135             columns.txt
#
#    stageOrder      prevTask
# 0           1
# 1           1  initial_data
# 2           1  initial_data
# 3           1  initial_data
# 4           1
# 5           1  initial_data
# 6           1  initial_data
# 7           1  initial_data
# 8           1
# 9           1  initial_data
# (1800, 18)

# %%
def mark_final_data(df):
    # Filter out write operations with empty prevTask
    write_ops = df[(df["operation"] == 0) & (df["prevTask"].astype(str).str.strip() == '')]

    # Build a mapping of stageOrder -> set of fileNames read in that stage
    read_files_by_stage = (
        df[df["operation"] == 1]
        .groupby("stageOrder")["fileName"]
        .apply(set)
        .to_dict()
    )

    for idx, row in write_ops.iterrows():
        file_written = row["fileName"]
        stage_written = row["stageOrder"]
        stage_to_check = stage_written + 1

        if file_written not in read_files_by_stage.get(stage_to_check, set()):
            df.at[idx, "prevTask"] = "final_data"

mark_final_data(wf_pfs_df)
# print(wf_pfs_df.head(20))

# %%
# Expand the dataframe for multi-nodes configuration calculation
def expand_df(wf_pfs_df):

    # Create a new DataFrame to store updated rows
    updated_rows = []

    # Iterate through each row in the DataFrame
    for index, row in wf_pfs_df.iterrows():
        NUM_NODES = row['numNodesList']  # Extract the list of numNodes
        print(f"NUM_NODES: {NUM_NODES}")
        for num_nodes in NUM_NODES:
            # Create a copy of the current row
            new_row = row.copy()
            
            # Update the numNodes and tasksPerNode for the new row
            tasksPerNode = math.ceil(row['parallelism'] / num_nodes)
            new_row['tasksPerNode'] = tasksPerNode
            new_row['numNodes'] = num_nodes
            
            
            # Append the updated row to the list
            updated_rows.append(new_row)

    # Create a new DataFrame with the updated rows
    expanded_df = pd.DataFrame(updated_rows)

    # Reset the index of the expanded DataFrame
    expanded_df.reset_index(drop=True, inplace=True)

    # # Print the updated DataFrame for verification
    # print(expanded_df.shape)
    # print(expanded_df.head())
    
    return expanded_df


if MULTI_NODES:
    wf_pfs_df = expand_df(wf_pfs_df)
    # Print the updated DataFrame for verification
    if DEBUG:
        print(wf_pfs_df.shape)
        print(wf_pfs_df.head())

# for rows when parallelism is 1, update numNodes to 1
for index, row in wf_pfs_df.iterrows():
    if row['parallelism'] == 1:
        wf_pfs_df.at[index, 'numNodes'] = 1

# %%
# Print list of unique taskNames
wf_pfs_df['taskName'].unique()
# Out:
# array(['individuals', 'frequency', 'mutation_overlap', 'sifting',
#        'individuals_merge'], dtype=object)

# %%
# Save the updated DataFrame to a CSV file
wf_pfs_df.to_csv(f'./analyzed_data/{test_folders[0]}.csv', index=False)

task_name_to_parallelism
# Out:
# {'individuals': 300,
#  'individuals_merge': 10,
#  'sifting': 10,
#  'mutation_overlap': 10,
#  'frequency': 10}

# %%
# Calculate I/O time per taskName
write_sub_df = wf_pfs_df[wf_pfs_df['operation'] == 0]
read_sub_df = wf_pfs_df[wf_pfs_df['operation'] == 1]

task_io_time_total = wf_pfs_df.groupby('taskName')['totalTime'].sum()
task_io_time_write = write_sub_df.groupby('taskName')['totalTime'].sum()
task_io_time_read = read_sub_df.groupby('taskName')['totalTime'].sum()

task_io_time_adjust = {"read": 0, "write": 0}
total_wf_io_time = 0
total_wf_io_time_write = 0
total_wf_io_time_read = 0
print("Total I/O time per taskName:")
# NUM_NODES is a fixed number now
for task, write_time in task_io_time_write.items():
    # Adjust I/O time by parallelism and number of nodes
    write_time_adjusted = write_time / (task_name_to_parallelism[task] * NUM_NODES)
    task_io_time_adjust["write"] += write_time_adjusted
    total_wf_io_time_write += write_time_adjusted
    total_wf_io_time += write_time_adjusted
    print(f" {task} (write): {write_time_adjusted} (sec)")

for task, read_time in task_io_time_read.items():
    # Adjust I/O time by parallelism and number of nodes
    read_time_adjusted = read_time / (task_name_to_parallelism[task] * NUM_NODES)
    task_io_time_adjust["read"] += read_time_adjusted
    total_wf_io_time_read += read_time_adjusted
    total_wf_io_time += read_time_adjusted
    print(f" {task} (read): {read_time_adjusted} (sec)")

print(f"Total I/O time per workflow: {total_wf_io_time}")
# Out:
# Total I/O time per taskName:
#  frequency (write): 0.01182337785 (sec)
#  individuals (write): 4.496766333333333e-06 (sec)
#  individuals_merge (write): 5.513027e-05 (sec)
#  mutation_overlap (write): 0.00083436507 (sec)
#  sifting (write): 2.3969059999999998e-05 (sec)
#  frequency (read): 0.02121502092 (sec)
#  individuals (read): 3.960484083507333 (sec)
#  individuals_merge (read): 0.040972154999999996 (sec)
#  mutation_overlap (read): 0.00233166633 (sec)
#  sifting (read): 0.98425757022 (sec)
# Total I/O time per workflow: 5.022001834993667

# %%
wf_pfs_df.head(5)
# Out:
#   operation randomOffset   transferSize  aggregateFilesizeMB numTasks  \
# 0         0            0   81791.000000             0.078002      300
# 1         1            1    8191.921474          2421.758036      300
# 2         1            1    8191.921474          2421.758036      300
# 3         1            1    8191.912230          2421.794365      300
# 4         0            0  101056.000000             0.096375      300
#
#   parallelism  totalTime numNodesList numNodes tasksPerNode        trMiB  \
# 0         300   0.000049         [10]       10           30  1593.503085
# 1         300  19.632952         [10]       10           30   123.351699
# 2         300  19.632952         [10]       10           30   123.351699
# 3         300  19.658824         [10]       10           30   123.191215
# 4         300   0.000050         [10]       10           30  1917.557288
#
#   storageType opCount     taskName      taskPID                fileName  \
# 0           1       1  individuals   6818-dc111  chr2n-2201-2401.tar.gz
# 1           1  309988  individuals   6818-dc111     ALL.chr2.250000.vcf
# 2           1  309988  individuals   6818-dc111             columns.txt
# 3           1  309993  individuals  25051-dc135     ALL.chr3.250000.vcf
# 4           1       1  individuals  25051-dc135  chr3n-1201-1401.tar.gz
#
#    stageOrder      prevTask
# 0           1
# 1           1  initial_data
# 2           1  initial_data
# 3           1  initial_data
# 4           1

# %% [markdown]
# # Build Workflow Graph
# Get max stage order for iteration
# ## First layers Nodes:
# - stageOrder == 0
#     - Add row as node attributes
#     - Need node "order"
#
# ## Middle layers
# - Find previous layer nodes  (stageOrder -1)
#  - Find if has the sane fileName, and make sure operation is 0 in stageOrder-1 and 1 in stageOrder
#  - link edge, calculate IOI and SPM
#
# ## Final Layer
# - When stageOrder reached max, stops

# %%
import networkx as nx

# Initialize the workflow graph as a directed graph
WFG = nx.DiGraph()

# Get the unique and sorted stage orders
stage_order_list = sorted(int(x) for x in wf_pfs_df['stageOrder'].unique())
print(stage_order_list)

# Dictionary to store task nodes by stage and task name
stage_task_node_dict = {}


# Add nodes to the graph
for i, row in wf_pfs_df.iterrows():
    nodeName = f"{row['taskName']}:{row['taskPID']}:{row['fileName']}"  # Unique node identifier
    new_nodeData = row.to_dict()  # Node attributes as dictionary
    stageOrder = row['stageOrder']
    taskName = row['taskName']

    # if "openmm" in nodeName:
    #     print(f"Processing node: {nodeName}")

    # Check if the node already exists
    if WFG.has_node(nodeName):
        # Update node data by replacing NaN values with new valid values
        existing_nodeData = WFG.nodes[nodeName]
        for key, value in new_nodeData.items():
            if key in existing_nodeData:
                # Replace NaN with valid value if applicable
                if (
                    (existing_nodeData[key] is None or isinstance(existing_nodeData[key], float) and math.isnan(existing_nodeData[key])) 
                    and value is not None and not (isinstance(value, float) and math.isnan(value))
                ):
                    existing_nodeData[key] = value
            else:
                # Add the new key-value pair
                existing_nodeData[key] = value
        # Update the node data in the graph
        WFG.nodes[nodeName].update(existing_nodeData)
    else:
        # Add the node with attributes to the graph
        WFG.add_node(nodeName, **new_nodeData)

    # Populate the stage-task-node dictionary
    stage_task_node_dict.setdefault(stageOrder, {}).setdefault(taskName, []).append(nodeName)

# Show the number of nodes and edges in the graph
print(f"Number of nodes: {WFG.number_of_nodes()}")
print(f"First five nodes:")
for info in list(WFG.nodes(data=True))[:5]:
    print(info)

print(f"Number of edges: {WFG.number_of_edges()}")
# Out:
# [1, 2, 3]
# Number of nodes: 1800
# First five nodes:
# ('individuals:6818-dc111:chr2n-2201-2401.tar.gz', {'operation': 0, 'randomOffset': 0, 'transferSize': 81791.0, 'aggregateFilesizeMB': 0.0780019760131836, 'numTasks': 300, 'parallelism': 300, 'totalTime': 4.895e-05, 'numNodesList': [10], 'numNodes': 10, 'tasksPerNode': 30, 'trMiB': 1593.503085049716, 'storageType': 1, 'opCount': 1, 'taskName': 'individuals', 'taskPID': '6818-dc111', 'fileName': 'chr2n-2201-2401.tar.gz', 'stageOrder': 1, 'prevTask': ''})
# ('individuals:6818-dc111:ALL.chr2.250000.vcf', {'operation': 1, 'randomOffset': 1, 'transferSize': 8191.921474379654, 'aggregateFilesizeMB': 2421.75803565979, 'numTasks': 300, 'parallelism': 300, 'totalTime': 19.632952451, 'numNodesList': [10], 'numNodes': 10, 'tasksPerNode': 30, 'trMiB': 123.35169871694148, 'storageType': 1, 'opCount': 309988, 'taskName': 'individuals', 'taskPID': '6818-dc111', 'fileName': 'ALL.chr2.250000.vcf', 'stageOrder': 1, 'prevTask': 'initial_data'})
# ('individuals:6818-dc111:columns.txt', {'operation': 1, 'randomOffset': 1, 'transferSize': 8191.921474379654, 'aggregateFilesizeMB': 2421.75803565979, 'numTasks': 300, 'parallelism': 300, 'totalTime': 19.632952451, 'numNodesList': [10], 'numNodes': 10, 'tasksPerNode': 30, 'trMiB': 123.35169871694148, 'storageType': 1, 'opCount': 309988, 'taskName': 'individuals', 'taskPID': '6818-dc111', 'fileName': 'columns.txt', 'stageOrder': 1, 'prevTask': 'initial_data'})
# ('individuals:25051-dc135:ALL.chr3.250000.vcf', {'operation': 1, 'randomOffset': 1, 'transferSize': 8191.912230276168, 'aggregateFilesizeMB': 2421.794364929199, 'numTasks': 300, 'parallelism': 300, 'totalTime': 19.658823658, 'numNodesList': [10], 'numNodes': 10, 'tasksPerNode': 30, 'trMiB': 123.19121464542307, 'storageType': 1, 'opCount': 309993, 'taskName': 'individuals', 'taskPID': '25051-dc135', 'fileName': 'ALL.chr3.250000.vcf', 'stageOrder': 1, 'prevTask': 'initial_data'})
# ('individuals:25051-dc135:chr3n-1201-1401.tar.gz', {'operation': 0, 'randomOffset': 0, 'transferSize': 101056.0, 'aggregateFilesizeMB': 0.09637451171875, 'numTasks': 300, 'parallelism': 300, 'totalTime': 5.0259e-05, 'numNodesList': [10], 'numNodes': 10, 'tasksPerNode': 30, 'trMiB': 1917.557287625102, 'storageType': 1, 'opCount': 1, 'taskName': 'individuals', 'taskPID': '25051-dc135', 'fileName': 'chr3n-1201-1401.tar.gz', 'stageOrder': 1, 'prevTask': ''})
# Number of edges: 0

# %%
def add_producer_consumer_edge(WFG, prod_nodes, cons_nodes):
    """
    Add edges between producer and consumer nodes, calculating edge attributes for each storage type.
    """
    for taskName, prevNodeNames in prod_nodes.items():
        for prod_node_name in prevNodeNames:
            prod_fileName = WFG.nodes[prod_node_name]['fileName'].strip()
            
            max_op_count = WFG.nodes[prod_node_name]['opCount']

            for cons_task_name, currNodeNames in cons_nodes.items():
                for cons_node_name in currNodeNames:
                    if WFG.nodes[cons_node_name].get('prevTask') == taskName:
                        cons_fileName = WFG.nodes[cons_node_name]['fileName'].strip()

                        # Check if file names match
                        if prod_fileName == cons_fileName:
                            edge_attributes = {}

                            # Calculate edge attributes for each storage type
                            for storage in ['ssd', 'beegfs']:
                                prod_keys = [
                                    key for key in WFG.nodes[prod_node_name].keys()
                                    if key.startswith(f'estimated_trMiB_{storage}_')
                                ]
                                cons_keys = [
                                    key for key in WFG.nodes[cons_node_name].keys()
                                    if key.startswith(f'estimated_trMiB_{storage}_')
                                ]

                                for prod_key in prod_keys:
                                    try:
                                        n_prod = int(prod_key.split('_')[-1][:-1])
                                    except ValueError:
                                        continue

                                    prod_estimated_trMiB = WFG.nodes[prod_node_name].get(prod_key)
                                    if prod_estimated_trMiB is None or math.isnan(prod_estimated_trMiB):
                                        continue

                                    for cons_key in cons_keys:
                                        try:
                                            n_cons = int(cons_key.split('_')[-1][:-1])
                                        except ValueError:
                                            continue

                                        cons_estimated_trMiB = WFG.nodes[cons_node_name].get(cons_key)
                                        if cons_estimated_trMiB is None or math.isnan(cons_estimated_trMiB):
                                            continue

                                        prod_aggregateFilesizeMB = WFG.nodes[prod_node_name]['aggregateFilesizeMB']
                                        cons_aggregateFilesizeMB = WFG.nodes[cons_node_name]['aggregateFilesizeMB']
                                        prod_opCount = WFG.nodes[prod_node_name]['opCount']
                                        cons_opCount = WFG.nodes[cons_node_name]['opCount']
                                        
                                        # Get the attribute that starts with "estimated_ts_slope_{storage}_"
                                        prod_slope_key = [
                                            key for key in WFG.nodes[prod_node_name].keys()
                                            if key.startswith(f'estimated_ts_slope_{storage}_{n_prod}p')
                                        ][0]
                                        cons_slope_key = [
                                            key for key in WFG.nodes[cons_node_name].keys()
                                            if key.startswith(f'estimated_ts_slope_{storage}_{n_cons}p')
                                        ][0]
                                        prod_ts_slope = WFG.nodes[prod_node_name][prod_slope_key]
                                        cons_ts_slope = WFG.nodes[prod_node_name][cons_slope_key]
                                        
                                        # prod_op_weight = prod_opCount / (prod_opCount + cons_opCount)
                                        # cons_op_weight = cons_opCount / (prod_opCount + cons_opCount)
                                        # estT_prod = prod_opCount * prod_aggregateFilesizeMB / (prod_estimated_trMiB )
                                        # estT_cons = cons_opCount * cons_aggregateFilesizeMB / (cons_estimated_trMiB )
                                        
                                        # TS increases -> OP decrease => Perform Increase, less time
                                        # TS decrease -> OP increases => Perform Decrease, more time

                                        if prod_ts_slope > 0 :
                                            # If transfer_size has increased I/O affects, means it's becoming larger, then OP_count becomes smaller
                                            # but if OP count is large, means the transfer size is skwered with one large I/O operation
                                            # Thus penalize using OP count
                                            # but if OP count is small, it won't affect much
                                            estT_prod = prod_opCount * prod_aggregateFilesizeMB / prod_estimated_trMiB
                                        else:
                                            # If transfer size has decreased I/O affects, means it's becoming smaller, then operation count becomes larger
                                            # but if OP count is smal, means the transfer size is skwered with small total file size
                                            # Thus reward using OP count
                                            # but if OP count is large, it should have been reflected in the estimated_trMiB
                                            estT_prod = (1/prod_opCount) * prod_aggregateFilesizeMB / prod_estimated_trMiB
                                            
                                        if cons_ts_slope > 0:
                                            estT_cons = cons_opCount * cons_aggregateFilesizeMB / cons_estimated_trMiB 
                                        else:
                                            estT_cons = (1/cons_opCount) * cons_aggregateFilesizeMB / cons_estimated_trMiB
                                        
                                        SPM = estT_prod / estT_cons if estT_cons > 0 else float('inf')

                                        edge_attributes.update({
                                            f'estT_prod_{storage}_{n_prod}p': estT_prod,
                                            f'estT_cons_{storage}_{n_cons}p': estT_cons,
                                            f'SPM_{storage}_{n_prod}_{n_cons}p': SPM,
                                            'prod_aggregateFilesizeMB': prod_aggregateFilesizeMB,
                                            'cons_aggregateFilesizeMB': cons_aggregateFilesizeMB,
                                            'prod_max_parallelism': WFG.nodes[prod_node_name]['parallelism'],
                                            'cons_max_parallelism': WFG.nodes[cons_node_name]['parallelism'],
                                        })

                            # Add or update the edge in the graph
                            if WFG.has_edge(prod_node_name, cons_node_name):
                                WFG.edges[prod_node_name, cons_node_name].update(edge_attributes)
                            else:
                                WFG.add_edge(prod_node_name, cons_node_name, **edge_attributes)



def handle_initial_stage(WFG, cons_nodes):
    """
    Handle the initial stage where there is no producer, only consumers.
    Calculate and store `estT_cons` for each consumer node as node attributes
    with placeholders for producer-related values.
    """
    for cons_task_name, currNodeNames in cons_nodes.items():
        for cons_node_name in currNodeNames:
            # Update node attributes
            node_attributes = {}

            # Calculate node attributes for each storage type
            for storage in ['ssd', 'beegfs']:
                cons_keys = [
                    key for key in WFG.nodes[cons_node_name].keys()
                    if key.startswith(f'estimated_trMiB_{storage}_')
                ]

                for cons_key in cons_keys:
                    try:
                        # Extract the parallelism level from the key (e.g., estimated_trMiB_ssd_4p)
                        n_cons = int(cons_key.split('_')[-1][:-1])
                    except ValueError:
                        continue

                    cons_estimated_trMiB = WFG.nodes[cons_node_name].get(cons_key)

                    # Skip invalid or missing values
                    if cons_estimated_trMiB is None or math.isnan(cons_estimated_trMiB):
                        continue

                    cons_aggregateFilesizeMB = WFG.nodes[cons_node_name]['aggregateFilesizeMB']
                    cons_opCount = WFG.nodes[cons_node_name]['opCount']

                    # Calculate estimated task I/O time as intensity for consumer
                    estT_cons = (cons_opCount * cons_aggregateFilesizeMB) / cons_estimated_trMiB

                    # Store node attributes
                    node_attributes.update({
                        f'estT_prod_{storage}_0p': 0,  # Placeholder
                        f'estT_cons_{storage}_{n_cons}p': estT_cons,
                        'prod_aggregateFilesizeMB': 0,  # Placeholder
                        'cons_aggregateFilesizeMB': cons_aggregateFilesizeMB,
                        'prod_max_parallelism': 0,  # Placeholder
                        'cons_max_parallelism': WFG.nodes[cons_node_name]['parallelism'],
                    })

            # Update the node attributes in the graph
            WFG.nodes[cons_node_name].update(node_attributes)

for currOrder in stage_order_list:
    cons_nodes = stage_task_node_dict.get(currOrder, {})
    if currOrder == 0:
        # Handle stage 0
        if INITIAL_STAGE:
            handle_initial_stage(WFG, cons_nodes)
    else:
        # Add edges between producer and consumer nodes
        prevOrder = currOrder - 1
        prod_nodes = stage_task_node_dict.get(prevOrder, {})
        add_producer_consumer_edge(WFG, prod_nodes, cons_nodes)
